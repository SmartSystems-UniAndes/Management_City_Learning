# %%
from Agent import Agent
import gym
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
env = gym.make('Pendulum-v0')
agent = Agent(input_dims=env.observation_space.shape, env=env, n_actions = env.action_space.shape[0])
n_games = 250
figure_file = 'plots/pendulum.png'

best_score = env.reward_range[0]
score_history = []
load_checkpoint = False

if load_checkpoint:
    n_steps = 0
    while n_steps <= agent.batch_size:
        observation = env.reset()
        action = env.action_space.sample()
        observation_, reward, done, info = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        n_steps +=1
    agent.learn()
    agent.load_models()
    evaluate = True
else:
    evaluate = False

for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        action = agent.choose_action(observation, evaluate)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.remember(observation, action, reward, observation_, done)
        if not load_checkpoint:
            agent.learn()
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])
    
    if avg_score > best_score:
        best_score = avg_score
        if not load_checkpoint:
            agent.save_models()
    print("episode ", i, "score %.1f" % score, 'avg score %.1f' % avg_score)
    
x = [i+1 for i in range(n_games)]
plot_learning_curve(x, score_history, figure_file)
# Out:
# .... saving models ....
# episode  0 score -1170.4 avg score -1170.4
# episode  1 score -1467.7 avg score -1319.0
# episode  2 score -1667.0 avg score -1435.0
# episode  3 score -1743.3 avg score -1512.1
# episode  4 score -1436.1 avg score -1496.9
# episode  5 score -1373.9 avg score -1476.4
# episode  6 score -1190.2 avg score -1435.5
# episode  7 score -1377.2 avg score -1428.2
# episode  8 score -1169.5 avg score -1399.5
# episode  9 score -1347.2 avg score -1394.2
# episode  10 score -1299.1 avg score -1385.6
# episode  11 score -1122.8 avg score -1363.7
# episode  12 score -1098.6 avg score -1343.3
# episode  13 score -1144.6 avg score -1329.1
# episode  14 score -1293.1 avg score -1326.7
# episode  15 score -878.2 avg score -1298.7
# episode  16 score -1175.3 avg score -1291.4
# episode  17 score -1050.1 avg score -1278.0
# episode  18 score -884.0 avg score -1257.3
# episode  19 score -826.5 avg score -1235.7
# episode  20 score -1071.4 avg score -1227.9
# episode  21 score -870.8 avg score -1211.7
# episode  22 score -1196.0 avg score -1211.0
# episode  23 score -783.9 avg score -1193.2
# .... saving models ....
# episode  24 score -520.5 avg score -1166.3
# .... saving models ....
# episode  25 score -519.2 avg score -1141.4
# .... saving models ....
# episode  26 score -665.6 avg score -1123.8
# .... saving models ....
# episode  27 score -372.3 avg score -1096.9
# .... saving models ....
# episode  28 score -122.2 avg score -1063.3
# .... saving models ....
# episode  29 score -373.7 avg score -1040.3
# .... saving models ....
# episode  30 score -121.3 avg score -1010.7
# .... saving models ....
# episode  31 score -125.7 avg score -983.0
# .... saving models ....
# episode  216 score -235.4 avg score -258.4
# episode  217 score -123.1 avg score -258.3
# episode  218 score -127.1 avg score -258.4
# episode  219 score -127.1 avg score -258.5
# episode  220 score -362.9 avg score -260.9
# episode  221 score -126.5 avg score -260.9
# episode  222 score -355.8 avg score -263.2
# episode  223 score -355.3 avg score -263.3
# episode  224 score -238.5 avg score -264.5
# episode  225 score -124.8 avg score -261.0
# episode  226 score -474.5 avg score -259.4
# episode  227 score -248.2 avg score -260.6
# episode  228 score -124.1 avg score -258.2
# episode  229 score -244.1 avg score -259.4
# episode  230 score -239.9 avg score -261.8
# episode  231 score -476.0 avg score -264.2
# episode  232 score -476.5 avg score -267.7
# episode  233 score -124.4 avg score -269.0
# episode  234 score -1.0 avg score -267.8
# episode  235 score -367.0 avg score -267.8
# episode  236 score -122.8 avg score -262.7
# episode  237 score -121.9 avg score -261.5
# episode  238 score -366.6 avg score -261.5
# episode  239 score -381.2 avg score -264.0
# episode  240 score -239.2 avg score -265.2
# episode  241 score -122.4 avg score -265.2
# episode  242 score -123.4 avg score -265.2
# episode  243 score -367.9 avg score -263.8
# episode  244 score -122.4 avg score -263.8
# episode  245 score -126.9 avg score -261.5
# episode  246 score -121.6 avg score -262.7
# episode  247 score -126.5 avg score -261.6
# episode  248 score -664.3 avg score -263.5
# episode  249 score -241.4 avg score -262.2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-176a69e8c7a2> in <module>
#      44
#      45 x = [i+1 for i in range(n_games)]
# ---> 46 plot_learning_curve(x, score_history, figure_file)
#      47
#
# <ipython-input-5-eb585aafefa3> in plot_learning_curve(x, scores, figure_file)
#       5     plt.plot(x, running_avg)
#       6     plt.title('Running average of previous 100 scores')
# ----> 7     plt.savefig(figure_file)
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# ~\Anaconda3\envs\tensorflow2.4-gpu\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2159                 fp = builtins.open(filename, "r+b")
#    2160             else:
# -> 2161                 fp = builtins.open(filename, "w+b")
#    2162
#    2163         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/pendulum.png'
