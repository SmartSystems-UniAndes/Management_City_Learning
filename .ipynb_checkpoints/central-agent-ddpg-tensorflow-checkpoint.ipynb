# %% [markdown]
# # Case Study PV Review Management
#
# This code is used as a case study example for the paper "Machine and Deep Learning in PhotovoltaicSystems: A Review". Using a Deep Deterministic Policy Gradient model, the idea is to reduce the consumption of energy of a CityLearn environment with one building that has cooling storage control.

# %%
import sys
sys.path.append('/Users/jfgf1/Documents/Universidad/Decimo Semesre/Tesis/Tesis Electrica/CityLearn/CityLearn/DDPG_Agent')
from DDPG_Agent.Agent import Agent
import matplotlib.pyplot as plt
import gym
import tensorflow as tf
import numpy as np
from citylearn import  CityLearn
from pathlib import Path
import time

# %%
def plot_learning_curve(x, scores, score_start_history, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg, 'r', label = 'Average Reward')
    plt.vlines(x, 0, scores, linestyles = 'dotted', colors = 'blue' )
    plt.plot(x, scores, 'bo', label = 'Episode Reward' )
    plt.legend(loc = 'lower right')
    plt.title('Episode Reward for EMS using DDPG agent for storage')
    plt.ylabel('Episode Reward')
    plt.xlabel('Episode Number')
    plt.savefig(figure_file)

# %% [markdown]
# The building information used for the case study can be seen in the next line of code:

# %%
# Central agent controlling one of the buildings using the OpenAI Stable Baselines
climate_zone = 1
data_path = Path("data/Climate_Zone_"+str(climate_zone))
building_attributes = data_path / 'building_attributes.json'
weather_file = data_path / 'weather_data.csv'
solar_profile = data_path / 'solar_generation_1kW.csv'
building_state_actions = 'buildings_state_action_space.json'
building_ids = ['Building_4']
objective_function = ['ramping','1-load_factor','average_daily_peak','peak_demand','net_electricity_consumption','quadratic']
env = CityLearn(data_path, building_attributes, weather_file, solar_profile, building_ids, buildings_states_actions = building_state_actions, cost_function = objective_function, central_agent = True, verbose = 1)

# %%
env.get_building_information()
# Out:
# {'Building_4': {'building_type': 4,
#   'climate_zone': 1,
#   'solar_power_capacity (kW)': 40,
#   'Annual_DHW_demand (kWh)': 0,
#   'Annual_cooling_demand (kWh)': 280239.0,
#   'Annual_nonshiftable_electrical_demand (kWh)': 36978.9,
#   'Correlations_DHW': {},
#   'Correlations_cooling_demand': {},
#   'Correlations_non_shiftable_load': {}}}

# %%
agent = Agent(input_dims = (9,), env=env, n_actions = env.action_space.shape[0],
             max_size = 100000, tau = 0.0003, fc1 = 800, fc2 = 800, batch_size = 1024, noise = 0.1,
             actor_lr = 0.0001, critic_lr = 0.0002, gamma = 0.99) #0.0002 700 400 400 1024
#env.observation_space.shape
n_games = 50
figure_file = 'plots/cityBuild.png'

best_score = env.reward_range[0]
score_history = []
score_start_history = []
load_checkpoint = False
indexes_states = [0, 1, 2, 3, 15, 21, 22, 23, 24]

if load_checkpoint:
    n_steps = 0
    while n_steps <= agent.batch_size:
        observation = env.reset()
        observation = [observation[i] for i in indexes_states]
        action = env.action_space.sample()
        observation_, reward, done, info = env.step(action)
        observation_ = [observation_[i] for i in indexes_states]
        agent.remember(observation, action, reward, observation_, done)
        n_steps +=1
    agent.learn()
    agent.load_models()
    evaluate = True
else:
    evaluate = False
    
for i in range(n_games):
    evaluate = False
    observation = env.reset()
    done = False
    score = 0
    j = 0
    agent.noise.reset()
    while j < 4:
        observation, reward, done, info = env.step([0.3])
        j +=1
    observation = [observation[i] for i in indexes_states]
    score_start_history.append(reward)
    while not done:
        action = agent.choose_action(observation, evaluate)
        observation_, reward, done, info = env.step(np.array(action))
        observation_ = [observation_[i] for i in indexes_states]
        score += reward
        agent.remember(observation, action, reward, observation_, done)
        if not load_checkpoint:
            agent.learn()
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        if not load_checkpoint:
            agent.save_models()
    print("episode ", i, "score %.1f" % score, 'avg score %.1f' % avg_score)
    
    
x = [i + 1 for i in range(n_games)]
plot_learning_curve(x, score_history, score_start_history, figure_file)
# Out:
# Cumulated reward: -415.673888266427
# .... saving models ....
# episode  0 score -415.4 avg score -415.4
# Cumulated reward: -293.8032879125011
# .... saving models ....
# episode  1 score -293.5 avg score -354.5
# Cumulated reward: -163.16901558315757
# .... saving models ....
# episode  2 score -162.9 avg score -290.6
# Cumulated reward: -114.03188813328057
# .... saving models ....
# episode  3 score -113.8 avg score -246.4
# Cumulated reward: -111.7272791656177
# .... saving models ....
# episode  4 score -111.4 avg score -219.4
# Cumulated reward: -80.80169540960601
# .... saving models ....
# episode  5 score -80.5 avg score -196.3
# Cumulated reward: -78.47683867472101
# .... saving models ....
# episode  6 score -78.2 avg score -179.4
# Cumulated reward: -24.482719348174925
# .... saving models ....
# episode  7 score -24.2 avg score -160.0
# Cumulated reward: -13.230790862740966
# .... saving models ....
# episode  8 score -13.0 avg score -143.7
# Cumulated reward: 0.7186851396161749
# .... saving models ....
# episode  9 score 1.0 avg score -129.2
# Cumulated reward: 4.343510491298122
# .... saving models ....
# episode  10 score 4.6 avg score -117.0
# Cumulated reward: 23.593638166996012
# .... saving models ....
# episode  11 score 23.9 avg score -105.3
# Cumulated reward: 14.83236240456312
# .... saving models ....
# episode  12 score 15.1 avg score -96.0
# Cumulated reward: 30.553234305095724
# .... saving models ....
# episode  13 score 30.8 avg score -87.0
# Cumulated reward: 28.898113336886286
# .... saving models ....
# episode  14 score 29.2 avg score -79.2
# Cumulated reward: 39.743611628181746
# .... saving models ....
# episode  15 score 40.0 avg score -71.8
# Cumulated reward: 2.9730179565909376
# .... saving models ....
# episode  16 score 3.3 avg score -67.4
# Cumulated reward: -0.35242974765971447
# .... saving models ....
# episode  17 score -0.1 avg score -63.6
# Cumulated reward: 13.234888249899159
# .... saving models ....
# episode  18 score 13.5 avg score -59.6
# Cumulated reward: 34.631937973996
# .... saving models ....
# episode  19 score 34.9 avg score -54.8
# Cumulated reward: -10.319742047875849
# .... saving models ....
# episode  20 score -10.0 avg score -52.7
# Cumulated reward: 3.0376992031120387
# .... saving models ....
# episode  21 score 3.3 avg score -50.2
# Cumulated reward: 10.023135801003937
# .... saving models ....
# episode  22 score 10.3 avg score -47.5
# Cumulated reward: 7.698215529302864
# .... saving models ....
# episode  23 score 8.0 avg score -45.2
# Cumulated reward: 17.78733353396494
# .... saving models ....
# episode  24 score 18.1 avg score -42.7
# Cumulated reward: -10.11900239171494
# .... saving models ....
# episode  25 score -9.8 avg score -41.4
# Cumulated reward: -4.660187432515052
# .... saving models ....
# episode  26 score -4.4 avg score -40.0
# Cumulated reward: 0.29443809192417314
# .... saving models ....
# episode  27 score 0.6 avg score -38.6
# Cumulated reward: 11.423628493874023
# .... saving models ....
# episode  28 score 11.7 avg score -36.9
# Cumulated reward: 7.142390855523685
# .... saving models ....
# episode  29 score 7.4 avg score -35.4
# Cumulated reward: 6.387756909284126
# .... saving models ....
# episode  30 score 6.7 avg score -34.0
# Cumulated reward: -6.274599758310896
# .... saving models ....
# episode  31 score -6.0 avg score -33.2
# Cumulated reward: 7.88007156971259
# .... saving models ....
# episode  32 score 8.2 avg score -31.9
# Cumulated reward: 3.1012652636099203
# .... saving models ....
# episode  33 score 3.4 avg score -30.9
# Cumulated reward: -11.178940909162847
# .... saving models ....
# episode  34 score -10.9 avg score -30.3
# Cumulated reward: 5.013937276470609
# .... saving models ....
# episode  35 score 5.3 avg score -29.3
# Cumulated reward: 20.212556938883697
# .... saving models ....
# episode  36 score 20.5 avg score -28.0
# Cumulated reward: 43.9060828382656
# .... saving models ....
# episode  37 score 44.2 avg score -26.1
# Cumulated reward: 30.118433260123247
# .... saving models ....
# episode  38 score 30.4 avg score -24.6
# Cumulated reward: 25.280623180062936
# .... saving models ....
# episode  39 score 25.6 avg score -23.4
# Cumulated reward: 17.400398741328832
# .... saving models ....
# episode  40 score 17.7 avg score -22.4
# Cumulated reward: 20.35336247663817
# .... saving models ....
# episode  41 score 20.6 avg score -21.3
# Cumulated reward: 10.630495420586142
# .... saving models ....
# episode  42 score 10.9 avg score -20.6
# Cumulated reward: 28.630153273946863
# .... saving models ....
# episode  43 score 28.9 avg score -19.5
# Cumulated reward: 13.03914446403496
# .... saving models ....
# episode  44 score 13.3 avg score -18.7
# Cumulated reward: 17.126091565824023
# .... saving models ....
# episode  45 score 17.4 avg score -17.9
# Cumulated reward: -1.6799744831994066
# .... saving models ....
# episode  46 score -1.4 avg score -17.6
# Cumulated reward: 24.43976559753272
# .... saving models ....
# episode  47 score 24.7 avg score -16.7
# Cumulated reward: 21.687712096155025
# .... saving models ....
# episode  48 score 22.0 avg score -15.9
# Cumulated reward: 22.78593098581795
# .... saving models ....
# episode  49 score 23.1 avg score -15.1

# %%
plot_learning_curve(x, score_history, score_start_history, figure_file)

# %%
observation_ = env.reset()
done = False
counter = []
evaluate = True
j = 0
while j < 4:
    observation_, reward, done, info = env.step([0.3])
    j +=1
observation_ = [observation_[i] for i in indexes_states]

while done==False:
    action = agent.choose_action(observation_, evaluate)
    observation_, reward, done, info = env.step(np.array(action))
    observation_ = [observation_[i] for i in indexes_states]
    print(observation_[-2])
    print(action)
    print(observation_[2])
    print(reward)
    counter.append(reward)
env.cost()
# Out:
# 0.9940000000000001
# tf.Tensor([-0.18979579], shape=(1,), dtype=float32)
# 6.0
# -1.936e-05
# 0.988036
# tf.Tensor([-0.3222664], shape=(1,), dtype=float32)
# 7.0
# -1.8489999999999997e-05
# 0.982107784
# tf.Tensor([-0.04896735], shape=(1,), dtype=float32)
# 8.0
# -2.025e-05
# 0.976215137296
# tf.Tensor([-0.33328828], shape=(1,), dtype=float32)
# 9.0
# -9.960335999999999e-06
# 0.9697135165753168
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.009422973184
# 0.9627455487970696
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.016833505536
# 0.9468493059469798
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.021609588004000004
# 0.9023820771013928
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.019805495824
# 0.8304375643032276
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.022808248575999997
# 0.7493355736455263
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.025601280015999997
# 0.6677473831266368
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.011805691715999999
# 0.5861812667276143
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0030514576000000002
# 0.5139103889513844
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.00035868572099999996
# 0.490827431974458
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 19.0
# -0.00256036
# 0.4775605551125485
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 20.0
# -0.0004
# 0.4662430996047962
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 21.0
# -0.00036480999999999997
# 0.4565601548539433
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 22.0
# -0.00042436
# 0.4498158414283571
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 23.0
# -0.0005522500000000001
# 0.4458788222641613
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 24.0
# -0.00056169
# 0.4432035493305763
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00017161000000000002
# 0.44054432803459287
# tf.Tensor([-0.3278548], shape=(1,), dtype=float32)
# 2.0
# -2.116e-05
# 0.5742131295750827
# tf.Tensor([0.13631207], shape=(1,), dtype=float32)
# 3.0
# 0.9754958545560001
# 0.6973983060531407
# tf.Tensor([0.12663046], shape=(1,), dtype=float32)
# 4.0
# 0.986010787824
# 0.6932139162168219
# tf.Tensor([-0.14513867], shape=(1,), dtype=float32)
# 5.0
# -1.6000000000000003e-05
# 0.6890546327195209
# tf.Tensor([-0.01733826], shape=(1,), dtype=float32)
# 6.0
# -2.2089999999999997e-05
# 0.6849203049232039
# tf.Tensor([-0.17964512], shape=(1,), dtype=float32)
# 7.0
# -1.6809999999999997e-05
# 0.6808107830936646
# tf.Tensor([-0.12131848], shape=(1,), dtype=float32)
# 8.0
# -1.5210000000000002e-05
# 0.6763342668891394
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 9.0
# -3.19225e-07
# 0.6714803243563311
# tf.Tensor([-0.32678103], shape=(1,), dtype=float32)
# 10.0
# -0.00163216
# 0.6751096515962405
# tf.Tensor([0.00765821], shape=(1,), dtype=float32)
# 11.0
# -5.8568409e-05
# 0.671058993686663
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -3.701505600000001e-05
# 0.667032639724543
# tf.Tensor([-0.3333331], shape=(1,), dtype=float32)
# 13.0
# -0.008506926289
# 0.6630304438861956
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.00041571132099999994
# 0.6590522612228784
# tf.Tensor([-0.33325943], shape=(1,), dtype=float32)
# 15.0
# -0.00036035428900000005
# 0.6550979476555412
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.000323424256
# 0.6511673599696078
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.000122810724
# 0.6472603558097902
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.00011041806399999999
# 0.6433767936749315
# tf.Tensor([-0.33326364], shape=(1,), dtype=float32)
# 19.0
# -0.00571536
# 0.6395165329128819
# tf.Tensor([-0.33302307], shape=(1,), dtype=float32)
# 20.0
# -0.007447690000000002
# 0.6356794337154046
# tf.Tensor([-0.33298972], shape=(1,), dtype=float32)
# 21.0
# -0.00614656
# 0.6318653571131122
# tf.Tensor([-0.32672554], shape=(1,), dtype=float32)
# 22.0
# -0.00254016
# 0.8947797375755666
# tf.Tensor([0.26670557], shape=(1,), dtype=float32)
# 23.0
# -0.016939282801000002
# 0.9624956668704883
# tf.Tensor([0.07308461], shape=(1,), dtype=float32)
# 24.0
# -0.0025627893760000004
# 1.0
# tf.Tensor([0.33329156], shape=(1,), dtype=float32)
# 1.0
# -0.001058070784
# 0.9940000000000001
# tf.Tensor([-0.10119244], shape=(1,), dtype=float32)
# 2.0
# -2.116e-05
# 0.988036
# tf.Tensor([-0.03289421], shape=(1,), dtype=float32)
# 3.0
# -1.6000000000000003e-05
# 1.0
# tf.Tensor([0.07363738], shape=(1,), dtype=float32)
# 4.0
# -0.00011839616100000002
# 0.9940000000000001
# tf.Tensor([-0.28568956], shape=(1,), dtype=float32)
# 5.0
# -1.5210000000000002e-05
# 0.988036
# tf.Tensor([-0.12928353], shape=(1,), dtype=float32)
# 6.0
# -1.369e-05
# 1.0
# tf.Tensor([0.3021126], shape=(1,), dtype=float32)
# 7.0
# -0.000131813361
# 0.9940000000000001
# tf.Tensor([-0.32064644], shape=(1,), dtype=float32)
# 8.0
# -2.116e-05
# 0.9876948841722256
# tf.Tensor([-0.3281649], shape=(1,), dtype=float32)
# 9.0
# -1.3017664e-05
# 0.9817687148671922
# tf.Tensor([-0.3332825], shape=(1,), dtype=float32)
# 10.0
# -0.003971394361
# 0.975878102577989
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.008017411600000001
# 0.9700228339625211
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.014478586929
# 0.9642026969587459
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.021776904899999998
# 0.9584174807769934
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.024853522500000003
# 0.952262690466821
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.019035444961
# 0.9435675093108807
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.006139819449
# 0.936996462047617
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0024134621290000003
# 0.9313744832753312
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.00046790016100000005
# 0.9257862363756793
# tf.Tensor([-0.3320322], shape=(1,), dtype=float32)
# 19.0
# -0.00529984
# 0.9202315189574253
# tf.Tensor([-0.33300832], shape=(1,), dtype=float32)
# 20.0
# -0.005069440000000001
# 0.9147101298436806
# tf.Tensor([-0.33313414], shape=(1,), dtype=float32)
# 21.0
# -0.00636804
# 0.9092218690646185
# tf.Tensor([-0.33328453], shape=(1,), dtype=float32)
# 22.0
# -0.00285156
# 0.9037665378502309
# tf.Tensor([-0.33111453], shape=(1,), dtype=float32)
# 23.0
# -0.00047089
# 0.8983439386231294
# tf.Tensor([-0.32559216], shape=(1,), dtype=float32)
# 24.0
# -0.00059536
# 0.8929538749913908
# tf.Tensor([-0.31692415], shape=(1,), dtype=float32)
# 1.0
# -0.00019880999999999998
# 0.8875961517414425
# tf.Tensor([-0.19212312], shape=(1,), dtype=float32)
# 2.0
# -1.8489999999999997e-05
# 0.9248292746772615
# tf.Tensor([0.0425587], shape=(1,), dtype=float32)
# 3.0
# -0.000576528121
# 1.0
# tf.Tensor([0.09738775], shape=(1,), dtype=float32)
# 4.0
# -0.001328310916
# 1.0
# tf.Tensor([0.31742024], shape=(1,), dtype=float32)
# 5.0
# -4.7265625e-05
# 0.9940000000000001
# tf.Tensor([-0.11342439], shape=(1,), dtype=float32)
# 6.0
# -2.116e-05
# 0.988036
# tf.Tensor([-0.06628171], shape=(1,), dtype=float32)
# 7.0
# -2.116e-05
# 1.0
# tf.Tensor([0.04525905], shape=(1,), dtype=float32)
# 8.0
# -0.00013644576099999998
# 1.0
# tf.Tensor([0.0543798], shape=(1,), dtype=float32)
# 9.0
# -1.5649936e-05
# 0.9933430361835457
# tf.Tensor([-0.33007264], shape=(1,), dtype=float32)
# 10.0
# -0.0005133396489999999
# 0.9873829779664445
# tf.Tensor([-0.33332378], shape=(1,), dtype=float32)
# 11.0
# -0.000227466724
# 0.9814586800986457
# tf.Tensor([-0.333288], shape=(1,), dtype=float32)
# 12.0
# -0.00010184846400000002
# 0.9755699280180538
# tf.Tensor([-0.07096312], shape=(1,), dtype=float32)
# 13.0
# -0.002106534609
# 0.9697165084499455
# tf.Tensor([-0.06733431], shape=(1,), dtype=float32)
# 14.0
# -0.0037300334760000005
# 0.9638982093992459
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.002837266756
# 0.9581148201428504
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.0062489025
# 0.9523661312219933
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0024994000359999996
# 0.9466519344346613
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.00012909504400000004
# 0.9409720228280534
# tf.Tensor([-0.12772962], shape=(1,), dtype=float32)
# 19.0
# -0.005625
# 0.9353261906910851
# tf.Tensor([-0.30638897], shape=(1,), dtype=float32)
# 20.0
# -0.007276089999999999
# 0.9297142335469386
# tf.Tensor([-0.27698854], shape=(1,), dtype=float32)
# 21.0
# -0.00863041
# 0.9241359481456569
# tf.Tensor([-0.33044022], shape=(1,), dtype=float32)
# 22.0
# -0.0029702500000000002
# 1.0
# tf.Tensor([0.33326072], shape=(1,), dtype=float32)
# 23.0
# -0.0033083203240000005
# 1.0
# tf.Tensor([0.3324455], shape=(1,), dtype=float32)
# 24.0
# -0.0008570256250000002
# 1.0
# tf.Tensor([0.33231762], shape=(1,), dtype=float32)
# 1.0
# -0.00030888062500000003
# 0.9940000000000001
# tf.Tensor([-0.29831904], shape=(1,), dtype=float32)
# 2.0
# -2.025e-05
# 0.988036
# tf.Tensor([-0.08157083], shape=(1,), dtype=float32)
# 3.0
# -2.116e-05
# 0.982107784
# tf.Tensor([-0.13961318], shape=(1,), dtype=float32)
# 4.0
# -2.5e-05
# 1.0
# tf.Tensor([0.32957336], shape=(1,), dtype=float32)
# 5.0
# -0.000196364169
# 1.0
# tf.Tensor([0.27044958], shape=(1,), dtype=float32)
# 6.0
# -5.1480625000000005e-05
# 1.0
# tf.Tensor([0.06227162], shape=(1,), dtype=float32)
# 7.0
# -4.7265625e-05
# 1.0
# tf.Tensor([0.15391299], shape=(1,), dtype=float32)
# 8.0
# -4.7265625e-05
# 1.0
# tf.Tensor([0.21522215], shape=(1,), dtype=float32)
# 9.0
# -2.58064e-07
# 1.0
# tf.Tensor([0.33018678], shape=(1,), dtype=float32)
# 10.0
# -0.011808516888999998
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.023547516304
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.030511006276000008
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.043361398756
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.037718300944
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.030255123599999996
# 0.9645356993933907
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.017863659025000003
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.004734540864
# 0.952995994285848
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.000286320241
# 0.9472780183201329
# tf.Tensor([-0.08180287], shape=(1,), dtype=float32)
# 19.0
# -0.006889000000000002
# 0.9415943502102121
# tf.Tensor([-0.3287323], shape=(1,), dtype=float32)
# 20.0
# -0.005791210000000001
# 0.9359447841089508
# tf.Tensor([-0.3324275], shape=(1,), dtype=float32)
# 21.0
# -0.0054464399999999994
# 0.9303291154042971
# tf.Tensor([-0.22356755], shape=(1,), dtype=float32)
# 22.0
# -0.0024304899999999996
# 0.9247471407118713
# tf.Tensor([-0.17948091], shape=(1,), dtype=float32)
# 23.0
# -0.0005382399999999999
# 0.9191986578675999
# tf.Tensor([-0.2911235], shape=(1,), dtype=float32)
# 24.0
# -0.00044521
# 1.0
# tf.Tensor([0.33328778], shape=(1,), dtype=float32)
# 1.0
# -0.002149342321
# 0.9940000000000001
# tf.Tensor([-0.3321485], shape=(1,), dtype=float32)
# 2.0
# -0.00016129
# 1.0
# tf.Tensor([0.2127055], shape=(1,), dtype=float32)
# 3.0
# -8.3448225e-05
# 0.9940000000000001
# tf.Tensor([-0.02322694], shape=(1,), dtype=float32)
# 4.0
# -2.304e-05
# 0.988036
# tf.Tensor([-0.23870972], shape=(1,), dtype=float32)
# 5.0
# -1.8489999999999997e-05
# 0.982107784
# tf.Tensor([-0.31733894], shape=(1,), dtype=float32)
# 6.0
# -1.8489999999999997e-05
# 0.976215137296
# tf.Tensor([-0.07853278], shape=(1,), dtype=float32)
# 7.0
# -2.304e-05
# 0.9703578464722239
# tf.Tensor([-0.16784011], shape=(1,), dtype=float32)
# 8.0
# -2.2089999999999997e-05
# 0.964245119243805
# tf.Tensor([-0.3284465], shape=(1,), dtype=float32)
# 9.0
# -2.6634240000000004e-06
# 0.9584596485283422
# tf.Tensor([-0.32721674], shape=(1,), dtype=float32)
# 10.0
# -0.013431651025
# 0.9527088906371721
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.026677342224000006
# 0.9469926372933491
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.038000044096
# 0.941310681469589
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.044584744801000005
# 0.9356628173807715
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.047657509636
# 0.930048840476487
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.042330593536
# 0.924468547433628
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.025106085601000003
# 0.9189217361490263
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.006406401599999999
# 0.9134082057321321
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -6.076225e-06
# 0.9079277564977394
# tf.Tensor([-0.32400867], shape=(1,), dtype=float32)
# 19.0
# -0.00497025
# 0.9024801899587529
# tf.Tensor([-0.33110034], shape=(1,), dtype=float32)
# 20.0
# -0.005184
# 0.8970653088190004
# tf.Tensor([-0.33188105], shape=(1,), dtype=float32)
# 21.0
# -0.005776
# 0.8916829169660863
# tf.Tensor([-0.33240372], shape=(1,), dtype=float32)
# 22.0
# -0.0030913599999999996
# 0.8863328194642898
# tf.Tensor([-0.33281726], shape=(1,), dtype=float32)
# 23.0
# -0.00047961
# 0.881014822547504
# tf.Tensor([-0.33318228], shape=(1,), dtype=float32)
# 24.0
# -0.00056169
# 0.8757287336122188
# tf.Tensor([-0.32959738], shape=(1,), dtype=float32)
# 1.0
# -0.00052441
# 0.8704743612105456
# tf.Tensor([-0.3328945], shape=(1,), dtype=float32)
# 2.0
# -0.00017956000000000002
# 1.0
# tf.Tensor([0.16002643], shape=(1,), dtype=float32)
# 3.0
# -0.003367248784
# 1.0
# tf.Tensor([0.25392428], shape=(1,), dtype=float32)
# 4.0
# -4.8650625e-05
# 0.9940000000000001
# tf.Tensor([-0.03410943], shape=(1,), dtype=float32)
# 5.0
# -1.7639999999999997e-05
# 1.0
# tf.Tensor([0.26707232], shape=(1,), dtype=float32)
# 6.0
# -8.7142225e-05
# 1.0
# tf.Tensor([0.33322066], shape=(1,), dtype=float32)
# 7.0
# -4.8650625e-05
# 1.0
# tf.Tensor([0.3328573], shape=(1,), dtype=float32)
# 8.0
# -4.192562499999999e-05
# 1.0
# tf.Tensor([0.09520214], shape=(1,), dtype=float32)
# 9.0
# -5.041e-05
# 0.9940000000000001
# tf.Tensor([-0.32396632], shape=(1,), dtype=float32)
# 10.0
# -2.5599999999999998e-08
# 1.0
# tf.Tensor([0.04154297], shape=(1,), dtype=float32)
# 11.0
# -0.001402427601
# 1.0
# tf.Tensor([0.30657607], shape=(1,), dtype=float32)
# 12.0
# -0.0040755456
# 1.0
# tf.Tensor([0.02045043], shape=(1,), dtype=float32)
# 13.0
# -0.003251508484000001
# 1.0
# tf.Tensor([0.3175365], shape=(1,), dtype=float32)
# 14.0
# -0.004311498244
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.013108647048999998
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.008586246244
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0018527859360000002
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.0013471836159999998
# 0.9703578464722239
# tf.Tensor([-0.10526067], shape=(1,), dtype=float32)
# 19.0
# -0.008798440000000001
# 0.9645356993933907
# tf.Tensor([-0.32972598], shape=(1,), dtype=float32)
# 20.0
# -0.004515839999999999
# 1.0
# tf.Tensor([0.32933635], shape=(1,), dtype=float32)
# 21.0
# -0.002652044004
# 1.0
# tf.Tensor([0.33300653], shape=(1,), dtype=float32)
# 22.0
# -0.001031887129
# 1.0
# tf.Tensor([0.32512894], shape=(1,), dtype=float32)
# 23.0
# -0.0009266544809999999
# 0.9940000000000001
# tf.Tensor([-0.30048847], shape=(1,), dtype=float32)
# 24.0
# -0.0008584900000000001
# 0.988036
# tf.Tensor([-0.3326772], shape=(1,), dtype=float32)
# 1.0
# -0.0008584900000000001
# 0.982107784
# tf.Tensor([-0.09114048], shape=(1,), dtype=float32)
# 2.0
# -2.9160000000000002e-05
# 1.0
# tf.Tensor([0.10849078], shape=(1,), dtype=float32)
# 3.0
# -0.000222397569
# 0.9940000000000001
# tf.Tensor([-0.00467796], shape=(1,), dtype=float32)
# 4.0
# -2.8090000000000004e-05
# 1.0
# tf.Tensor([0.04511701], shape=(1,), dtype=float32)
# 5.0
# -9.0916225e-05
# 1.0
# tf.Tensor([0.22087994], shape=(1,), dtype=float32)
# 6.0
# -5.292562500000001e-05
# 1.0
# tf.Tensor([0.02434113], shape=(1,), dtype=float32)
# 7.0
# -4.4555625e-05
# 0.9940000000000001
# tf.Tensor([-0.3316257], shape=(1,), dtype=float32)
# 8.0
# -1.8489999999999997e-05
# 0.988036
# tf.Tensor([-0.33205104], shape=(1,), dtype=float32)
# 9.0
# -1.4554225e-05
# 1.0
# tf.Tensor([0.33295217], shape=(1,), dtype=float32)
# 10.0
# -2.1638410000000004e-06
# 1.0
# tf.Tensor([0.3331712], shape=(1,), dtype=float32)
# 11.0
# -1.1478543999999999e-05
# 1.0
# tf.Tensor([0.31096482], shape=(1,), dtype=float32)
# 12.0
# -0.0034027388890000006
# 0.9940000000000001
# tf.Tensor([-0.10157596], shape=(1,), dtype=float32)
# 13.0
# -0.002768232996
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.0030094001640000004
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.030038435856000006
# 0.976215137296
# tf.Tensor([-0.30349663], shape=(1,), dtype=float32)
# 16.0
# -0.016079761636
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0083320384
# 0.9645356993933907
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -2.1344400000000002e-05
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 19.0
# -0.0033872400000000006
# 0.952995994285848
# tf.Tensor([-0.31341773], shape=(1,), dtype=float32)
# 20.0
# -0.000576
# 0.9472780183201329
# tf.Tensor([-0.22710115], shape=(1,), dtype=float32)
# 21.0
# -0.00059049
# 0.98466567235329
# tf.Tensor([0.04307132], shape=(1,), dtype=float32)
# 22.0
# -0.0017762853159999999
# 1.0
# tf.Tensor([0.31767765], shape=(1,), dtype=float32)
# 23.0
# -0.0010437422490000002
# 1.0
# tf.Tensor([0.33325607], shape=(1,), dtype=float32)
# 24.0
# -0.0006287556249999999
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00024885062499999995
# 0.9939115625631696
# tf.Tensor([-0.26155663], shape=(1,), dtype=float32)
# 2.0
# -2.116e-05
# 1.0
# tf.Tensor([0.2953728], shape=(1,), dtype=float32)
# 3.0
# -8.77969e-05
# 0.9940000000000001
# tf.Tensor([-0.05930432], shape=(1,), dtype=float32)
# 4.0
# -2.2089999999999997e-05
# 1.0
# tf.Tensor([0.26614124], shape=(1,), dtype=float32)
# 5.0
# -8.5285225e-05
# 1.0
# tf.Tensor([0.23934895], shape=(1,), dtype=float32)
# 6.0
# -4.5900625e-05
# 1.0
# tf.Tensor([0.26569813], shape=(1,), dtype=float32)
# 7.0
# -5.0055625000000004e-05
# 1.0
# tf.Tensor([0.26321042], shape=(1,), dtype=float32)
# 8.0
# -4.5900625e-05
# 1.0
# tf.Tensor([0.02094791], shape=(1,), dtype=float32)
# 9.0
# -9.604e-05
# 1.0
# tf.Tensor([0.33108333], shape=(1,), dtype=float32)
# 10.0
# -1.0278436e-05
# 1.0
# tf.Tensor([0.33146793], shape=(1,), dtype=float32)
# 11.0
# -4.662158399999999e-05
# 0.9940000000000001
# tf.Tensor([-0.33102965], shape=(1,), dtype=float32)
# 12.0
# -0.00028767552099999996
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.0022833106560000006
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.034709180416000004
# 0.976215137296
# tf.Tensor([-0.33332548], shape=(1,), dtype=float32)
# 15.0
# -0.0048260809
# 0.9703578464722239
# tf.Tensor([-0.33289108], shape=(1,), dtype=float32)
# 16.0
# -0.002764761561
# 0.9645356993933907
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -3.24e-08
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.000291282489
# 1.0
# tf.Tensor([0.31875914], shape=(1,), dtype=float32)
# 19.0
# -0.010221614404000002
# 1.0
# tf.Tensor([0.33091757], shape=(1,), dtype=float32)
# 20.0
# -0.006444075624999999
# 1.0
# tf.Tensor([0.33143747], shape=(1,), dtype=float32)
# 21.0
# -0.007547265625
# 1.0
# tf.Tensor([0.3293628], shape=(1,), dtype=float32)
# 22.0
# -0.0028063506250000005
# 1.0
# tf.Tensor([0.3327868], shape=(1,), dtype=float32)
# 23.0
# -0.000518700625
# 1.0
# tf.Tensor([0.333297], shape=(1,), dtype=float32)
# 24.0
# -0.0006956406250000001
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00030888062500000003
# 0.9939241964827169
# tf.Tensor([-0.29720777], shape=(1,), dtype=float32)
# 2.0
# -1.7639999999999997e-05
# 1.0
# tf.Tensor([0.32989898], shape=(1,), dtype=float32)
# 3.0
# -8.217422499999998e-05
# 1.0
# tf.Tensor([0.14290136], shape=(1,), dtype=float32)
# 4.0
# -4.8650625e-05
# 1.0
# tf.Tensor([0.30690348], shape=(1,), dtype=float32)
# 5.0
# -5.292562500000001e-05
# 1.0
# tf.Tensor([0.28915966], shape=(1,), dtype=float32)
# 6.0
# -5.1480625000000005e-05
# 0.9940000000000001
# tf.Tensor([-0.32096773], shape=(1,), dtype=float32)
# 7.0
# -2.5e-05
# 1.0
# tf.Tensor([0.05809915], shape=(1,), dtype=float32)
# 8.0
# -8.5285225e-05
# 1.0
# tf.Tensor([0.19795363], shape=(1,), dtype=float32)
# 9.0
# -4.7679025000000004e-05
# 0.9940000000000001
# tf.Tensor([-0.2232918], shape=(1,), dtype=float32)
# 10.0
# -6.9505569e-05
# 1.0
# tf.Tensor([0.33225292], shape=(1,), dtype=float32)
# 11.0
# -0.001972869889
# 1.0
# tf.Tensor([0.23886746], shape=(1,), dtype=float32)
# 12.0
# -0.003853057329
# 1.0
# tf.Tensor([0.14451987], shape=(1,), dtype=float32)
# 13.0
# -0.0024682017609999997
# 1.0
# tf.Tensor([0.04178752], shape=(1,), dtype=float32)
# 14.0
# -0.0022402235610000003
# 0.9940000000000001
# tf.Tensor([-0.33332944], shape=(1,), dtype=float32)
# 15.0
# -0.019841821321
# 0.988036
# tf.Tensor([-0.3329965], shape=(1,), dtype=float32)
# 16.0
# -0.011280776521
# 0.982107784
# tf.Tensor([-0.33333242], shape=(1,), dtype=float32)
# 17.0
# -0.002746388836
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.000526427136
# 0.9703578464722239
# tf.Tensor([-0.29261184], shape=(1,), dtype=float32)
# 19.0
# -0.00677329
# 0.9645356993933907
# tf.Tensor([-0.3184713], shape=(1,), dtype=float32)
# 20.0
# -0.00515524
# 1.0
# tf.Tensor([0.19310938], shape=(1,), dtype=float32)
# 21.0
# -0.009163467076
# 1.0
# tf.Tensor([0.32147133], shape=(1,), dtype=float32)
# 22.0
# -0.003337950625
# 1.0
# tf.Tensor([0.3332106], shape=(1,), dtype=float32)
# 23.0
# -0.000828000625
# 1.0
# tf.Tensor([0.33328742], shape=(1,), dtype=float32)
# 24.0
# -0.0007826006249999999
# 1.0
# tf.Tensor([0.33331102], shape=(1,), dtype=float32)
# 1.0
# -0.000371525625
# 0.9939115625631696
# tf.Tensor([-0.31255648], shape=(1,), dtype=float32)
# 2.0
# -2.5e-05
# 1.0
# tf.Tensor([0.16315474], shape=(1,), dtype=float32)
# 3.0
# -0.00010140489999999998
# 1.0
# tf.Tensor([0.27990103], shape=(1,), dtype=float32)
# 4.0
# -5.8905624999999996e-05
# 1.0
# tf.Tensor([0.31886017], shape=(1,), dtype=float32)
# 5.0
# -5.1480625000000005e-05
# 1.0
# tf.Tensor([0.25894105], shape=(1,), dtype=float32)
# 6.0
# -5.5875625000000006e-05
# 0.9940000000000001
# tf.Tensor([-0.28131565], shape=(1,), dtype=float32)
# 7.0
# -2.025e-05
# 0.988036
# tf.Tensor([-0.17451577], shape=(1,), dtype=float32)
# 8.0
# -2.401e-05
# 1.0
# tf.Tensor([0.33332193], shape=(1,), dtype=float32)
# 9.0
# -2.6956863999999998e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.008676363609000001
# 0.9940000000000001
# tf.Tensor([-0.3333332], shape=(1,), dtype=float32)
# 11.0
# -0.019768922404
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.016958029729
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.024961156081
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.03222707136099999
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.008101980120999998
# 0.9645356993933907
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.007881178175999998
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0022357766559999996
# 0.952995994285848
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.0008263900089999998
# 0.9472780183201329
# tf.Tensor([-0.30689296], shape=(1,), dtype=float32)
# 19.0
# -0.00614656
# 1.0
# tf.Tensor([0.06039507], shape=(1,), dtype=float32)
# 20.0
# -0.012820579984000003
# 1.0
# tf.Tensor([0.32192743], shape=(1,), dtype=float32)
# 21.0
# -0.008041605624999998
# 0.9940000000000001
# tf.Tensor([-0.30224296], shape=(1,), dtype=float32)
# 22.0
# -0.00267289
# 1.0
# tf.Tensor([0.32525527], shape=(1,), dtype=float32)
# 23.0
# -0.000747202225
# 1.0
# tf.Tensor([0.33328915], shape=(1,), dtype=float32)
# 24.0
# -0.000509630625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00025201562499999996
# 0.9938989286436224
# tf.Tensor([-0.33200446], shape=(1,), dtype=float32)
# 2.0
# -2.116e-05
# 0.9879355350717607
# tf.Tensor([-0.21625018], shape=(1,), dtype=float32)
# 3.0
# -2.5e-05
# 1.0
# tf.Tensor([0.3309236], shape=(1,), dtype=float32)
# 4.0
# -0.00013273344099999998
# 1.0
# tf.Tensor([0.20249227], shape=(1,), dtype=float32)
# 5.0
# -4.8650625e-05
# 0.9940000000000001
# tf.Tensor([-0.33045438], shape=(1,), dtype=float32)
# 6.0
# -1.8489999999999997e-05
# 1.0
# tf.Tensor([0.28055084], shape=(1,), dtype=float32)
# 7.0
# -7.4563225e-05
# 1.0
# tf.Tensor([0.33216518], shape=(1,), dtype=float32)
# 8.0
# -3.6905625e-05
# 1.0
# tf.Tensor([0.33285642], shape=(1,), dtype=float32)
# 9.0
# -8.19025e-07
# 1.0
# tf.Tensor([0.33332723], shape=(1,), dtype=float32)
# 10.0
# -0.011283963076
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.024767834884
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.051547615681000004
# 1.0
# tf.Tensor([0.32607502], shape=(1,), dtype=float32)
# 13.0
# -0.053815184361
# 0.9940000000000001
# tf.Tensor([-0.3333332], shape=(1,), dtype=float32)
# 14.0
# -0.017044869136
# 0.988036
# tf.Tensor([-0.22829586], shape=(1,), dtype=float32)
# 15.0
# -0.0013956201639999998
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.0008289216810000001
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.001373665969
# 0.9703578464722239
# tf.Tensor([-0.28204876], shape=(1,), dtype=float32)
# 18.0
# -0.005079983076
# 0.9645356993933907
# tf.Tensor([-0.09387128], shape=(1,), dtype=float32)
# 19.0
# -0.007938810000000001
# 0.9587484851970303
# tf.Tensor([-0.08857737], shape=(1,), dtype=float32)
# 20.0
# -0.00707281
# 0.952995994285848
# tf.Tensor([-0.06094348], shape=(1,), dtype=float32)
# 21.0
# -0.0064
# 1.0
# tf.Tensor([0.33243066], shape=(1,), dtype=float32)
# 22.0
# -0.0047148822250000005
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 23.0
# -0.000478515625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 24.0
# -0.0006187656249999998
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.000315950625
# 1.0
# tf.Tensor([0.33332562], shape=(1,), dtype=float32)
# 2.0
# -0.000370755025
# 1.0
# tf.Tensor([0.33333296], shape=(1,), dtype=float32)
# 3.0
# -6.201562499999999e-05
# 1.0
# tf.Tensor([0.33326244], shape=(1,), dtype=float32)
# 4.0
# -6.201562499999999e-05
# 1.0
# tf.Tensor([0.31600302], shape=(1,), dtype=float32)
# 5.0
# -6.201562499999999e-05
# 1.0
# tf.Tensor([0.27189863], shape=(1,), dtype=float32)
# 6.0
# -6.201562499999999e-05
# 1.0
# tf.Tensor([0.07111797], shape=(1,), dtype=float32)
# 7.0
# -6.045062499999999e-05
# 0.9940000000000001
# tf.Tensor([-0.11915141], shape=(1,), dtype=float32)
# 8.0
# -3.0250000000000003e-05
# 1.0
# tf.Tensor([0.33333278], shape=(1,), dtype=float32)
# 9.0
# -1.8139081000000002e-05
# 0.9940000000000001
# tf.Tensor([-0.19355494], shape=(1,), dtype=float32)
# 10.0
# -0.004945746276000001
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.004031615025
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.007177986729000001
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.007861836889
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.012709180225
# 0.9645356993933907
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.011386810680999998
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.006026727424000001
# 0.952995994285848
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -1.0634121000000001e-05
# 0.9472780183201329
# tf.Tensor([-0.05349266], shape=(1,), dtype=float32)
# 18.0
# -0.0026624568010000004
# 0.9415943502102121
# tf.Tensor([-0.33332178], shape=(1,), dtype=float32)
# 19.0
# -0.00811801
# 0.9359447841089508
# tf.Tensor([-0.01409758], shape=(1,), dtype=float32)
# 20.0
# -0.007551609999999999
# 0.9303291154042971
# tf.Tensor([-0.20365195], shape=(1,), dtype=float32)
# 21.0
# -0.007921000000000001
# 0.9679141059580718
# tf.Tensor([0.04316697], shape=(1,), dtype=float32)
# 22.0
# -0.005988283456
# 0.9621066213223234
# tf.Tensor([-0.33332825], shape=(1,), dtype=float32)
# 23.0
# -0.000729
# 0.9563339815943894
# tf.Tensor([-0.33333105], shape=(1,), dtype=float32)
# 24.0
# -0.00083521
# 0.9505959777048231
# tf.Tensor([-0.33332765], shape=(1,), dtype=float32)
# 1.0
# -0.0008584900000000001
# 0.9448924018385941
# tf.Tensor([-0.33332342], shape=(1,), dtype=float32)
# 2.0
# -0.00032761
# 0.9392230474275626
# tf.Tensor([-0.32174134], shape=(1,), dtype=float32)
# 3.0
# -2.8090000000000004e-05
# 1.0
# tf.Tensor([0.32033625], shape=(1,), dtype=float32)
# 4.0
# -0.000984892689
# 0.9940000000000001
# tf.Tensor([-0.3175619], shape=(1,), dtype=float32)
# 5.0
# -2.601e-05
# 1.0
# tf.Tensor([0.06036532], shape=(1,), dtype=float32)
# 6.0
# -9.477022500000001e-05
# 1.0
# tf.Tensor([0.06864262], shape=(1,), dtype=float32)
# 7.0
# -4.5900625e-05
# 0.9940000000000001
# tf.Tensor([-0.05344782], shape=(1,), dtype=float32)
# 8.0
# -1.5210000000000002e-05
# 0.9877327859308672
# tf.Tensor([-0.30849734], shape=(1,), dtype=float32)
# 9.0
# -8.485568999999999e-06
# 0.981806389215282
# tf.Tensor([-0.04505364], shape=(1,), dtype=float32)
# 10.0
# -0.000184009225
# 0.9759155508799903
# tf.Tensor([-0.32804415], shape=(1,), dtype=float32)
# 11.0
# -4.9284000000000006e-08
# 0.9700600575747103
# tf.Tensor([-0.33331138], shape=(1,), dtype=float32)
# 12.0
# -6.864400000000001e-06
# 0.964239697229262
# tf.Tensor([-0.3332352], shape=(1,), dtype=float32)
# 13.0
# -1.5429183999999997e-05
# 1.0
# tf.Tensor([0.11302711], shape=(1,), dtype=float32)
# 14.0
# -0.001646087184
# 1.0
# tf.Tensor([0.13302618], shape=(1,), dtype=float32)
# 15.0
# -0.001401229489
# 0.9940000000000001
# tf.Tensor([-0.04545116], shape=(1,), dtype=float32)
# 16.0
# -0.001164652129
# 1.0
# tf.Tensor([0.04879184], shape=(1,), dtype=float32)
# 17.0
# -0.005095960996
# 1.0
# tf.Tensor([0.09586449], shape=(1,), dtype=float32)
# 18.0
# -0.0051710481
# 0.9940000000000001
# tf.Tensor([-0.25172317], shape=(1,), dtype=float32)
# 19.0
# -0.00474721
# 0.988036
# tf.Tensor([-0.26708975], shape=(1,), dtype=float32)
# 20.0
# -0.0025502499999999996
# 0.982107784
# tf.Tensor([-0.33331403], shape=(1,), dtype=float32)
# 21.0
# -0.00047961
# 0.976215137296
# tf.Tensor([-0.33327964], shape=(1,), dtype=float32)
# 22.0
# -0.00063504
# 0.9703578464722239
# tf.Tensor([-0.3329938], shape=(1,), dtype=float32)
# 23.0
# -0.0005382399999999999
# 0.9645356993933907
# tf.Tensor([-0.3197168], shape=(1,), dtype=float32)
# 24.0
# -0.00048841
# 1.0
# tf.Tensor([0.2800841], shape=(1,), dtype=float32)
# 1.0
# -0.0017244086759999999
# 1.0
# tf.Tensor([0.18008515], shape=(1,), dtype=float32)
# 2.0
# -5.4390625e-05
# 1.0
# tf.Tensor([0.3330875], shape=(1,), dtype=float32)
# 3.0
# -4.5900625e-05
# 1.0
# tf.Tensor([0.33203033], shape=(1,), dtype=float32)
# 4.0
# -5.1480625000000005e-05
# 1.0
# tf.Tensor([0.33245283], shape=(1,), dtype=float32)
# 5.0
# -4.8650625e-05
# 1.0
# tf.Tensor([0.33314735], shape=(1,), dtype=float32)
# 6.0
# -5.1480625000000005e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 7.0
# -4.5900625e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 8.0
# -5.0055625000000004e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 9.0
# -1.308736e-06
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.014443953489000001
# 1.0
# tf.Tensor([0.3295973], shape=(1,), dtype=float32)
# 11.0
# -0.032416562116
# 1.0
# tf.Tensor([0.33190987], shape=(1,), dtype=float32)
# 12.0
# -0.038397970116000005
# 1.0
# tf.Tensor([0.25374827], shape=(1,), dtype=float32)
# 13.0
# -0.04232935908100001
# 1.0
# tf.Tensor([0.33331537], shape=(1,), dtype=float32)
# 14.0
# -0.04321534168899999
# 1.0
# tf.Tensor([0.33324167], shape=(1,), dtype=float32)
# 15.0
# -0.03731773968399999
# 0.9940000000000001
# tf.Tensor([-0.33333284], shape=(1,), dtype=float32)
# 16.0
# -0.021877072281000002
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.008345918736
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -1.234321e-06
# 1.0
# tf.Tensor([0.23124662], shape=(1,), dtype=float32)
# 19.0
# -0.005596984969
# 1.0
# tf.Tensor([0.33302057], shape=(1,), dtype=float32)
# 20.0
# -0.000916575625
# 1.0
# tf.Tensor([0.33332843], shape=(1,), dtype=float32)
# 21.0
# -0.0008165306250000001
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 22.0
# -0.000722265625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 23.0
# -0.0007714506249999999
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 24.0
# -0.000760380625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00030888062500000003
# 0.9940000000000001
# tf.Tensor([-0.33327326], shape=(1,), dtype=float32)
# 2.0
# -1.7639999999999997e-05
# 1.0
# tf.Tensor([0.2553324], shape=(1,), dtype=float32)
# 3.0
# -8.9019225e-05
# 1.0
# tf.Tensor([0.33248612], shape=(1,), dtype=float32)
# 4.0
# -5.292562500000001e-05
# 1.0
# tf.Tensor([0.3332841], shape=(1,), dtype=float32)
# 5.0
# -5.7380625e-05
# 1.0
# tf.Tensor([0.32663566], shape=(1,), dtype=float32)
# 6.0
# -5.4390625e-05
# 1.0
# tf.Tensor([0.31835747], shape=(1,), dtype=float32)
# 7.0
# -5.7380625e-05
# 0.9940000000000001
# tf.Tensor([-0.05782609], shape=(1,), dtype=float32)
# 8.0
# -2.304e-05
# 0.988036
# tf.Tensor([-0.33333305], shape=(1,), dtype=float32)
# 9.0
# -5.363856e-06
# 0.9816403289767536
# tf.Tensor([-0.33328986], shape=(1,), dtype=float32)
# 10.0
# -0.017619642121
# 0.9753209337382882
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.03980344206400001
# 0.9694690081358585
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.040571627776
# 0.9636521940870433
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.04379602562499999
# 0.9578702809225209
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.049194352804
# 0.9521230592369859
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.036318068329
# 0.9464103208815638
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.021329434116
# 0.9407318589562744
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.006927565823999999
# 0.9350874678025368
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -2.8223999999999995e-08
# 0.9294769429957216
# tf.Tensor([-0.07680279], shape=(1,), dtype=float32)
# 19.0
# -0.0037699599999999997
# 0.9239000813377473
# tf.Tensor([-0.33060938], shape=(1,), dtype=float32)
# 20.0
# -0.000625
# 0.9183566808497208
# tf.Tensor([-0.33190274], shape=(1,), dtype=float32)
# 21.0
# -0.00059536
# 0.9128465407646225
# tf.Tensor([-0.33310372], shape=(1,), dtype=float32)
# 22.0
# -0.00070225
# 0.9073694615200348
# tf.Tensor([-0.33331752], shape=(1,), dtype=float32)
# 23.0
# -0.0006760000000000001
# 0.9019252447509146
# tf.Tensor([-0.3333307], shape=(1,), dtype=float32)
# 24.0
# -0.00063504
# 0.8965136932824093
# tf.Tensor([-0.33332825], shape=(1,), dtype=float32)
# 1.0
# -0.00019320999999999997
# 0.8910461736858843
# tf.Tensor([-0.2232506], shape=(1,), dtype=float32)
# 2.0
# -2.304e-05
# 1.0
# tf.Tensor([0.32922575], shape=(1,), dtype=float32)
# 3.0
# -0.002533612225
# 0.9940000000000001
# tf.Tensor([-0.13715568], shape=(1,), dtype=float32)
# 4.0
# -2.2089999999999997e-05
# 1.0
# tf.Tensor([0.3136273], shape=(1,), dtype=float32)
# 5.0
# -7.983422499999999e-05
# 1.0
# tf.Tensor([0.32737625], shape=(1,), dtype=float32)
# 6.0
# -3.8130625000000006e-05
# 1.0
# tf.Tensor([0.3041176], shape=(1,), dtype=float32)
# 7.0
# -3.6905625e-05
# 1.0
# tf.Tensor([0.30901814], shape=(1,), dtype=float32)
# 8.0
# -3.6905625e-05
# 1.0
# tf.Tensor([0.33309847], shape=(1,), dtype=float32)
# 9.0
# -1.6899999999999999e-10
# 1.0
# tf.Tensor([0.31596866], shape=(1,), dtype=float32)
# 10.0
# -0.013483157689
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.027304918564
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.033905698224999996
# 0.982107784
# tf.Tensor([-0.3333326], shape=(1,), dtype=float32)
# 13.0
# -0.0465912225
# 0.976215137296
# tf.Tensor([-0.33286038], shape=(1,), dtype=float32)
# 14.0
# -0.04947510489999999
# 0.9703578464722239
# tf.Tensor([-0.33291364], shape=(1,), dtype=float32)
# 15.0
# -0.042313312804
# 0.9645356993933907
# tf.Tensor([-0.33333284], shape=(1,), dtype=float32)
# 16.0
# -0.025737143184
# 0.9587484851970303
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.009779627664000002
# 0.952995994285848
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -9.3219025e-05
# 0.9472780183201329
# tf.Tensor([-0.33332998], shape=(1,), dtype=float32)
# 19.0
# -0.005476000000000001
# 0.9415943502102121
# tf.Tensor([-0.3332404], shape=(1,), dtype=float32)
# 20.0
# -0.0051122500000000005
# 0.9359447841089508
# tf.Tensor([-0.33332127], shape=(1,), dtype=float32)
# 21.0
# -0.004928039999999999
# 0.9303291154042971
# tf.Tensor([-0.05103283], shape=(1,), dtype=float32)
# 22.0
# -0.0023136099999999994
# 1.0
# tf.Tensor([0.33220297], shape=(1,), dtype=float32)
# 23.0
# -0.003228739684
# 1.0
# tf.Tensor([0.33228058], shape=(1,), dtype=float32)
# 24.0
# -0.0006390278409999999
# 1.0
# tf.Tensor([0.30430335], shape=(1,), dtype=float32)
# 1.0
# -0.000274730625
# 0.9940000000000001
# tf.Tensor([-0.28876656], shape=(1,), dtype=float32)
# 2.0
# -1.5210000000000002e-05
# 0.988036
# tf.Tensor([-0.0242349], shape=(1,), dtype=float32)
# 3.0
# -2.116e-05
# 1.0
# tf.Tensor([0.04140703], shape=(1,), dtype=float32)
# 4.0
# -0.00012501476100000003
# 1.0
# tf.Tensor([0.30205238], shape=(1,), dtype=float32)
# 5.0
# -4.192562499999999e-05
# 0.9940000000000001
# tf.Tensor([-0.29575804], shape=(1,), dtype=float32)
# 6.0
# -1.8489999999999997e-05
# 0.988036
# tf.Tensor([-0.29866374], shape=(1,), dtype=float32)
# 7.0
# -1.936e-05
# 0.982107784
# tf.Tensor([-0.0748905], shape=(1,), dtype=float32)
# 8.0
# -2.401e-05
# 1.0
# tf.Tensor([0.2949329], shape=(1,), dtype=float32)
# 9.0
# -0.000188183524
# 0.9933177683444513
# tf.Tensor([-0.33291757], shape=(1,), dtype=float32)
# 10.0
# -4.2432196e-05
# 0.9873578617343846
# tf.Tensor([-0.09476396], shape=(1,), dtype=float32)
# 11.0
# -0.00011491840000000001
# 1.0
# tf.Tensor([0.3333301], shape=(1,), dtype=float32)
# 12.0
# -0.0016825583609999999
# 1.0
# tf.Tensor([0.33331951], shape=(1,), dtype=float32)
# 13.0
# -0.0013938275560000002
# 1.0
# tf.Tensor([0.32967144], shape=(1,), dtype=float32)
# 14.0
# -0.001164925161
# 0.9940000000000001
# tf.Tensor([-0.07083201], shape=(1,), dtype=float32)
# 15.0
# -0.0020723435289999995
# 1.0
# tf.Tensor([0.24485824], shape=(1,), dtype=float32)
# 16.0
# -0.0030744807040000003
# 0.9940000000000001
# tf.Tensor([-0.29148644], shape=(1,), dtype=float32)
# 17.0
# -0.0032983197609999996
# 0.988036
# tf.Tensor([-0.16352764], shape=(1,), dtype=float32)
# 18.0
# -0.006028435449000001
# 0.982107784
# tf.Tensor([-0.30081058], shape=(1,), dtype=float32)
# 19.0
# -0.00606841
# 0.976215137296
# tf.Tensor([-0.25839555], shape=(1,), dtype=float32)
# 20.0
# -0.00776161
# 0.9703578464722239
# tf.Tensor([-0.28883502], shape=(1,), dtype=float32)
# 21.0
# -0.008427239999999999
# 0.9645356993933907
# tf.Tensor([-0.33182997], shape=(1,), dtype=float32)
# 22.0
# -0.0033640000000000002
# 1.0
# tf.Tensor([0.33325413], shape=(1,), dtype=float32)
# 23.0
# -0.0024740676
# 1.0
# tf.Tensor([0.3333123], shape=(1,), dtype=float32)
# 24.0
# -0.0007384806249999999
# 1.0
# tf.Tensor([0.33288905], shape=(1,), dtype=float32)
# 1.0
# -0.000341325625
# 0.9940000000000001
# tf.Tensor([-0.3094086], shape=(1,), dtype=float32)
# 2.0
# -1.936e-05
# 0.988036
# tf.Tensor([-0.00351948], shape=(1,), dtype=float32)
# 3.0
# -2.116e-05
# 1.0
# tf.Tensor([0.31752676], shape=(1,), dtype=float32)
# 4.0
# -0.000163968025
# 0.9940000000000001
# tf.Tensor([-0.0752392], shape=(1,), dtype=float32)
# 5.0
# -1.5210000000000002e-05
# 1.0
# tf.Tensor([0.30099297], shape=(1,), dtype=float32)
# 6.0
# -9.7851664e-05
# 1.0
# tf.Tensor([0.27376324], shape=(1,), dtype=float32)
# 7.0
# -5.117971600000001e-05
# 1.0
# tf.Tensor([0.15088029], shape=(1,), dtype=float32)
# 8.0
# -5.2620516000000006e-05
# 1.0
# tf.Tensor([0.13887537], shape=(1,), dtype=float32)
# 9.0
# -6.258392100000001e-05
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 10.0
# -1.4640999999999999e-06
# 0.988036
# tf.Tensor([-0.33332354], shape=(1,), dtype=float32)
# 11.0
# -0.00010530864399999999
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.017875689999999996
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.027947146276000007
# 0.9703578464722239
# tf.Tensor([-0.33332086], shape=(1,), dtype=float32)
# 14.0
# -0.0016590143610000002
# 0.9645356993933907
# tf.Tensor([-0.32786864], shape=(1,), dtype=float32)
# 15.0
# -0.000259049025
# 0.9587484851970303
# tf.Tensor([-0.04467459], shape=(1,), dtype=float32)
# 16.0
# -0.000112466025
# 0.952995994285848
# tf.Tensor([-0.30314857], shape=(1,), dtype=float32)
# 17.0
# -0.006275016225
# 0.9472780183201329
# tf.Tensor([-0.12778509], shape=(1,), dtype=float32)
# 18.0
# -0.006584186449000001
# 0.9415943502102121
# tf.Tensor([-0.19140485], shape=(1,), dtype=float32)
# 19.0
# -0.005929
# 0.9359447841089508
# tf.Tensor([-0.25038537], shape=(1,), dtype=float32)
# 20.0
# -0.00632025
# 0.9303291154042971
# tf.Tensor([-0.27207676], shape=(1,), dtype=float32)
# 21.0
# -0.00808201
# 0.9247471407118713
# tf.Tensor([-0.13073564], shape=(1,), dtype=float32)
# 22.0
# -0.0028196099999999993
# 0.9191986578675999
# tf.Tensor([-0.3332709], shape=(1,), dtype=float32)
# 23.0
# -0.0005569599999999999
# 0.9136834659203944
# tf.Tensor([-0.32736546], shape=(1,), dtype=float32)
# 24.0
# -0.0006100900000000001
# 0.9082013651248719
# tf.Tensor([-0.0982848], shape=(1,), dtype=float32)
# 1.0
# -0.00018225
# 0.9027521569341227
# tf.Tensor([-0.02002412], shape=(1,), dtype=float32)
# 2.0
# -0.00015376000000000002
# 1.0
# tf.Tensor([0.17071393], shape=(1,), dtype=float32)
# 3.0
# -0.0048370634010000005
# 1.0
# tf.Tensor([0.32865843], shape=(1,), dtype=float32)
# 4.0
# -5.5294096000000006e-05
# 0.9940000000000001
# tf.Tensor([-0.02979002], shape=(1,), dtype=float32)
# 5.0
# -2.304e-05
# 1.0
# tf.Tensor([0.18297848], shape=(1,), dtype=float32)
# 6.0
# -9.5160025e-05
# 1.0
# tf.Tensor([0.33312863], shape=(1,), dtype=float32)
# 7.0
# -4.8385936e-05
# 1.0
# tf.Tensor([0.3304507], shape=(1,), dtype=float32)
# 8.0
# -4.3230624999999994e-05
# 1.0
# tf.Tensor([0.33329123], shape=(1,), dtype=float32)
# 9.0
# -1.2609601000000001e-05
# 0.9932925005053569
# tf.Tensor([-0.333202], shape=(1,), dtype=float32)
# 10.0
# -0.000730674961
# 0.9873327455023247
# tf.Tensor([-0.33321005], shape=(1,), dtype=float32)
# 11.0
# -0.000270701209
# 0.9814087490293109
# tf.Tensor([-0.21239305], shape=(1,), dtype=float32)
# 12.0
# -0.0014722569000000002
# 0.9755202965351351
# tf.Tensor([-0.04040564], shape=(1,), dtype=float32)
# 13.0
# -0.004965598089000001
# 0.9696671747559241
# tf.Tensor([-0.3285086], shape=(1,), dtype=float32)
# 14.0
# -0.0036322318239999994
# 0.9638491717073885
# tf.Tensor([-0.33332172], shape=(1,), dtype=float32)
# 15.0
# -0.0018627855999999998
# 0.9580660766771442
# tf.Tensor([-0.3333326], shape=(1,), dtype=float32)
# 16.0
# -0.00020868691600000005
# 1.0
# tf.Tensor([0.10376976], shape=(1,), dtype=float32)
# 17.0
# -0.006608551849000001
# 0.9940000000000001
# tf.Tensor([-0.04010566], shape=(1,), dtype=float32)
# 18.0
# -0.003170478249
# 0.988036
# tf.Tensor([-0.33333144], shape=(1,), dtype=float32)
# 19.0
# -0.00531441
# 0.982107784
# tf.Tensor([-0.26652706], shape=(1,), dtype=float32)
# 20.0
# -0.005358240000000001
# 0.976215137296
# tf.Tensor([-0.32796985], shape=(1,), dtype=float32)
# 21.0
# -0.00470596
# 0.9703578464722239
# tf.Tensor([-0.2938788], shape=(1,), dtype=float32)
# 22.0
# -0.00319225
# 0.9645356993933907
# tf.Tensor([-0.33054733], shape=(1,), dtype=float32)
# 23.0
# -0.0006002500000000001
# 0.9587484851970303
# tf.Tensor([-0.3319075], shape=(1,), dtype=float32)
# 24.0
# -0.0004536899999999999
# 0.952995994285848
# tf.Tensor([-0.32563686], shape=(1,), dtype=float32)
# 1.0
# -0.00043264000000000003
# 0.9472780183201329
# tf.Tensor([-0.11872157], shape=(1,), dtype=float32)
# 2.0
# -0.00019880999999999998
# 1.0
# tf.Tensor([0.10890828], shape=(1,), dtype=float32)
# 3.0
# -0.001719180369
# 1.0
# tf.Tensor([0.3301751], shape=(1,), dtype=float32)
# 4.0
# -6.501196900000001e-05
# 1.0
# tf.Tensor([0.02599217], shape=(1,), dtype=float32)
# 5.0
# -7.1859529e-05
# 0.9940000000000001
# tf.Tensor([-0.23978928], shape=(1,), dtype=float32)
# 6.0
# -1.444e-05
# 1.0
# tf.Tensor([0.21553902], shape=(1,), dtype=float32)
# 7.0
# -0.000160833124
# 1.0
# tf.Tensor([0.33219266], shape=(1,), dtype=float32)
# 8.0
# -7.3685056e-05
# 1.0
# tf.Tensor([0.02068952], shape=(1,), dtype=float32)
# 9.0
# -2.4522303999999998e-05
# 0.9931029917121488
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.00041400040899999997
# 0.9871443737618759
# tf.Tensor([-0.06231611], shape=(1,), dtype=float32)
# 11.0
# -0.00019788048900000002
# 0.9812215075193046
# tf.Tensor([-0.3320034], shape=(1,), dtype=float32)
# 12.0
# -0.000784392049
# 0.9753341784741888
# tf.Tensor([-0.3332599], shape=(1,), dtype=float32)
# 13.0
# -2.1538881000000003e-05
# 0.9694821734033437
# tf.Tensor([-0.33166057], shape=(1,), dtype=float32)
# 14.0
# -0.0004909769640000001
# 0.9636652803629236
# tf.Tensor([-0.33304444], shape=(1,), dtype=float32)
# 15.0
# -9.946072899999999e-05
# 0.957883288680746
# tf.Tensor([-0.29906887], shape=(1,), dtype=float32)
# 16.0
# -0.000121550625
# 0.9521359889486616
# tf.Tensor([-0.3333323], shape=(1,), dtype=float32)
# 17.0
# -0.004149678723999999
# 0.9464231730149696
# tf.Tensor([-0.27741694], shape=(1,), dtype=float32)
# 18.0
# -0.005700552004
# 0.9407446339768798
# tf.Tensor([-0.06505377], shape=(1,), dtype=float32)
# 19.0
# -0.008172159999999998
# 0.9351001661730185
# tf.Tensor([-0.3149256], shape=(1,), dtype=float32)
# 20.0
# -0.0035640899999999994
# 0.9294895651759804
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 21.0
# -0.00051529
# 0.9239126277849246
# tf.Tensor([-0.3333332], shape=(1,), dtype=float32)
# 22.0
# -0.00059536
# 0.9183691520182149
# tf.Tensor([-0.33333182], shape=(1,), dtype=float32)
# 23.0
# -0.000529
# 0.9128589371061057
# tf.Tensor([-0.3331145], shape=(1,), dtype=float32)
# 24.0
# -0.0006002500000000001
# 0.907381783483469
# tf.Tensor([-0.3204236], shape=(1,), dtype=float32)
# 1.0
# -0.0006300099999999999
# 0.9019374927825682
# tf.Tensor([-0.17755781], shape=(1,), dtype=float32)
# 2.0
# -2.2089999999999997e-05
# 1.0
# tf.Tensor([0.11116724], shape=(1,), dtype=float32)
# 3.0
# -0.007133829443999999
# 1.0
# tf.Tensor([0.27697092], shape=(1,), dtype=float32)
# 4.0
# -8.379571599999999e-05
# 0.9940000000000001
# tf.Tensor([-0.00868832], shape=(1,), dtype=float32)
# 5.0
# -2.304e-05
# 0.988036
# tf.Tensor([-0.1611683], shape=(1,), dtype=float32)
# 6.0
# -2.601e-05
# 0.982107784
# tf.Tensor([-0.33074358], shape=(1,), dtype=float32)
# 7.0
# -2.7040000000000002e-05
# 0.976215137296
# tf.Tensor([-0.33254555], shape=(1,), dtype=float32)
# 8.0
# -2.304e-05
# 0.9703578464722239
# tf.Tensor([-0.10139825], shape=(1,), dtype=float32)
# 9.0
# -0.0013934542409999998
# 1.0
# tf.Tensor([0.2615021], shape=(1,), dtype=float32)
# 10.0
# -0.006313573764
# 0.9934188397008288
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 11.0
# -0.019715810569
# 0.9860054259146959
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.018540090244
# 0.971523595906206
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -0.020030174783999998
# 0.9247479210782925
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.024414687504
# 0.8574448348051075
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.024183671121000002
# 0.7866290519899295
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.011998573443999998
# 0.7133323623757867
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.0039017512960000003
# 0.6482579473404041
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -3.3454656e-05
# 0.6292076961997213
# tf.Tensor([-0.33266163], shape=(1,), dtype=float32)
# 19.0
# -0.00236196
# 0.6182690176392602
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 20.0
# -0.0006150400000000001
# 0.6117673073134935
# tf.Tensor([-0.33333308], shape=(1,), dtype=float32)
# 21.0
# -0.00047961
# 0.6078440250786685
# tf.Tensor([-0.33333203], shape=(1,), dtype=float32)
# 22.0
# -0.0005017600000000001
# 0.6041969609281965
# tf.Tensor([-0.333319], shape=(1,), dtype=float32)
# 23.0
# -0.00051529
# 0.6005717791626274
# tf.Tensor([-0.33295643], shape=(1,), dtype=float32)
# 24.0
# -0.00043680999999999993
# 0.5969683484876516
# tf.Tensor([-0.33287647], shape=(1,), dtype=float32)
# 1.0
# -0.00014641
# 0.5933865383967256
# tf.Tensor([-0.12062666], shape=(1,), dtype=float32)
# 2.0
# -1.369e-05
# 0.7017541680584619
# tf.Tensor([0.11192795], shape=(1,), dtype=float32)
# 3.0
# 0.993051943975
# 0.8118481483387121
# tf.Tensor([0.11430451], shape=(1,), dtype=float32)
# 4.0
# 0.995945367024
# 0.8069770594486798
# tf.Tensor([-0.06169558], shape=(1,), dtype=float32)
# 5.0
# -2.401e-05
# 0.8021351970919877
# tf.Tensor([-0.16419236], shape=(1,), dtype=float32)
# 6.0
# -2.601e-05
# 0.7973223859094357
# tf.Tensor([-0.16312805], shape=(1,), dtype=float32)
# 7.0
# -2.116e-05
# 0.7925384515939791
# tf.Tensor([-0.10258688], shape=(1,), dtype=float32)
# 8.0
# -2.025e-05
# 0.7874042032979992
# tf.Tensor([-0.05789022], shape=(1,), dtype=float32)
# 9.0
# -0.0017854850250000002
# 0.7819470107444735
# tf.Tensor([-0.33233553], shape=(1,), dtype=float32)
# 10.0
# -0.013402229824
# 0.7772553286800067
# tf.Tensor([-0.3282107], shape=(1,), dtype=float32)
# 11.0
# -0.017455958640999997
# 0.7725917967079267
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -0.020670963076
# 0.767956245927679
# tf.Tensor([-0.33333305], shape=(1,), dtype=float32)
# 13.0
# -0.031729584384
# 0.7558186924019815
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.036342084496
# 0.7155929575267288
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.028031800328999996
# 0.6635179160540566
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.016932515625
# 0.6120838067384479
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 17.0
# -0.007753330809000002
# 0.5806672165723653
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.00011147136400000001
# 0.5739741977079422
# tf.Tensor([-0.32996336], shape=(1,), dtype=float32)
# 19.0
# -0.00597529
# 0.5705303525216946
# tf.Tensor([-0.33333004], shape=(1,), dtype=float32)
# 20.0
# -0.006889000000000002
# 0.5671071704065644
# tf.Tensor([-0.3333125], shape=(1,), dtype=float32)
# 21.0
# -0.006707609999999999
# 0.563704527384125
# tf.Tensor([-0.33332676], shape=(1,), dtype=float32)
# 22.0
# -0.0022944099999999998
# 0.5603223002198203
# tf.Tensor([-0.33173788], shape=(1,), dtype=float32)
# 23.0
# -0.0005475599999999999
# 0.6150148210431542
# ...
# 5.0
# -1.444e-05
# 1.0
# tf.Tensor([0.33329907], shape=(1,), dtype=float32)
# 6.0
# -0.00013644576099999998
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 7.0
# -5.0055625000000004e-05
# 0.9940000000000001
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 8.0
# -1.7639999999999997e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 9.0
# -0.001288307449
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.009299323489
# 1.0
# tf.Tensor([0.3329467], shape=(1,), dtype=float32)
# 11.0
# -0.013798731024
# 0.9940000000000001
# tf.Tensor([-0.32598847], shape=(1,), dtype=float32)
# 12.0
# -0.035750490084000004
# 1.0
# tf.Tensor([0.09038524], shape=(1,), dtype=float32)
# 13.0
# -0.018720259684
# 0.9940000000000001
# tf.Tensor([-0.20293853], shape=(1,), dtype=float32)
# 14.0
# -0.021425933376000003
# 0.988036
# tf.Tensor([-0.24725485], shape=(1,), dtype=float32)
# 15.0
# -0.018884531241
# 0.982107784
# tf.Tensor([-0.33190426], shape=(1,), dtype=float32)
# 16.0
# -0.004013095801
# 0.976215137296
# tf.Tensor([-0.3332964], shape=(1,), dtype=float32)
# 17.0
# -0.002296134724
# 0.9703578464722239
# tf.Tensor([-0.33332315], shape=(1,), dtype=float32)
# 18.0
# -0.0007435438239999999
# 0.9645356993933907
# tf.Tensor([-0.07075877], shape=(1,), dtype=float32)
# 19.0
# -0.00288369
# 1.0
# tf.Tensor([0.33333027], shape=(1,), dtype=float32)
# 20.0
# -0.001507458276
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 21.0
# -0.000565250625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 22.0
# -0.000623750625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 23.0
# -0.000654080625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 24.0
# -0.000788205625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.000387105625
# 0.9940000000000001
# tf.Tensor([-0.33279023], shape=(1,), dtype=float32)
# 2.0
# -2.401e-05
# 0.988036
# tf.Tensor([-0.3332809], shape=(1,), dtype=float32)
# 3.0
# -1.936e-05
# 0.982107784
# tf.Tensor([-0.333223], shape=(1,), dtype=float32)
# 4.0
# -1.5210000000000002e-05
# 0.976215137296
# tf.Tensor([-0.13646019], shape=(1,), dtype=float32)
# 5.0
# -1.8489999999999997e-05
# 1.0
# tf.Tensor([0.11183549], shape=(1,), dtype=float32)
# 6.0
# -0.000269977761
# 1.0
# tf.Tensor([0.33330962], shape=(1,), dtype=float32)
# 7.0
# -5.4390625e-05
# 1.0
# tf.Tensor([0.3333277], shape=(1,), dtype=float32)
# 8.0
# -4.5900625e-05
# 1.0
# tf.Tensor([0.3332737], shape=(1,), dtype=float32)
# 9.0
# -0.0015546460409999999
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 10.0
# -0.011266548736
# 1.0
# tf.Tensor([0.23211108], shape=(1,), dtype=float32)
# 11.0
# -0.013969585248999999
# 0.9940000000000001
# tf.Tensor([-0.33256248], shape=(1,), dtype=float32)
# 12.0
# -0.020143841040999998
# 0.988036
# tf.Tensor([-0.23414747], shape=(1,), dtype=float32)
# 13.0
# -0.032805903376000006
# 0.982107784
# tf.Tensor([-0.33160543], shape=(1,), dtype=float32)
# 14.0
# -0.02828383968399999
# 1.0
# tf.Tensor([0.04794243], shape=(1,), dtype=float32)
# 15.0
# -0.020315371024
# 0.9940000000000001
# tf.Tensor([-0.32846725], shape=(1,), dtype=float32)
# 16.0
# -0.012888379729000001
# 0.988036
# tf.Tensor([-0.26987624], shape=(1,), dtype=float32)
# 17.0
# -0.003656499961
# 1.0
# tf.Tensor([0.21715298], shape=(1,), dtype=float32)
# 18.0
# -0.0006864924009999999
# 1.0
# tf.Tensor([0.33326772], shape=(1,), dtype=float32)
# 19.0
# -0.003621030625
# 1.0
# tf.Tensor([0.32452887], shape=(1,), dtype=float32)
# 20.0
# -0.000788205625
# 1.0
# tf.Tensor([0.32871902], shape=(1,), dtype=float32)
# 21.0
# -0.000623750625
# 1.0
# tf.Tensor([0.3261648], shape=(1,), dtype=float32)
# 22.0
# -0.0005700156250000001
# 1.0
# tf.Tensor([0.31259543], shape=(1,), dtype=float32)
# 23.0
# -0.000690375625
# 1.0
# tf.Tensor([0.33062562], shape=(1,), dtype=float32)
# 24.0
# -0.000551075625
# 1.0
# tf.Tensor([0.32603005], shape=(1,), dtype=float32)
# 1.0
# -0.00024258062500000005
# 1.0
# tf.Tensor([0.33331662], shape=(1,), dtype=float32)
# 2.0
# -4.356e-05
# 0.9940000000000001
# tf.Tensor([-0.3332008], shape=(1,), dtype=float32)
# 3.0
# -1.6000000000000003e-05
# 0.988036
# tf.Tensor([-0.33331954], shape=(1,), dtype=float32)
# 4.0
# -2.116e-05
# 0.982107784
# tf.Tensor([-0.32449043], shape=(1,), dtype=float32)
# 5.0
# -1.6809999999999997e-05
# 1.0
# tf.Tensor([0.3320789], shape=(1,), dtype=float32)
# 6.0
# -0.000196364169
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 7.0
# -5.292562500000001e-05
# 0.9940000000000001
# tf.Tensor([-0.3330739], shape=(1,), dtype=float32)
# 8.0
# -2.304e-05
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 9.0
# -0.0017203415290000003
# 1.0
# tf.Tensor([0.33333308], shape=(1,), dtype=float32)
# 10.0
# -0.013038442595999998
# 1.0
# tf.Tensor([0.21248762], shape=(1,), dtype=float32)
# 11.0
# -0.021747400899999998
# 0.9940000000000001
# tf.Tensor([-0.33226088], shape=(1,), dtype=float32)
# 12.0
# -0.018896076369
# 0.988036
# tf.Tensor([-0.3235717], shape=(1,), dtype=float32)
# 13.0
# -0.020136745216
# 0.982107784
# tf.Tensor([-0.33154887], shape=(1,), dtype=float32)
# 14.0
# -0.023006215684
# 0.976215137296
# tf.Tensor([-0.33330524], shape=(1,), dtype=float32)
# 15.0
# -0.021979545024999998
# 0.9703578464722239
# tf.Tensor([-0.33318385], shape=(1,), dtype=float32)
# 16.0
# -0.008285186529
# 0.9645356993933907
# tf.Tensor([-0.33025756], shape=(1,), dtype=float32)
# 17.0
# -0.000873143401
# 0.9587484851970303
# tf.Tensor([-0.3026715], shape=(1,), dtype=float32)
# 18.0
# -0.0012268206760000001
# 0.9773349959116242
# tf.Tensor([0.024339], shape=(1,), dtype=float32)
# 19.0
# -0.008580687423999998
# 0.9714709859361544
# tf.Tensor([-0.28546342], shape=(1,), dtype=float32)
# 20.0
# -0.00605284
# 0.9656421600205375
# tf.Tensor([-0.26277855], shape=(1,), dtype=float32)
# 21.0
# -0.005913610000000001
# 1.0
# tf.Tensor([0.1982263], shape=(1,), dtype=float32)
# 22.0
# -0.0047872561
# 1.0
# tf.Tensor([0.33224142], shape=(1,), dtype=float32)
# 23.0
# -0.000643890625
# 1.0
# tf.Tensor([0.33331504], shape=(1,), dtype=float32)
# 24.0
# -0.000518700625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.00030537562500000003
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 2.0
# -5.0623225e-05
# 0.9940000000000001
# tf.Tensor([-0.33225405], shape=(1,), dtype=float32)
# 3.0
# -1.936e-05
# 0.988036
# tf.Tensor([-0.3333155], shape=(1,), dtype=float32)
# 4.0
# -1.8489999999999997e-05
# 0.982107784
# tf.Tensor([-0.28129077], shape=(1,), dtype=float32)
# 5.0
# -1.8489999999999997e-05
# 0.976215137296
# tf.Tensor([-0.19095296], shape=(1,), dtype=float32)
# 6.0
# -2.025e-05
# 1.0
# tf.Tensor([0.32605416], shape=(1,), dtype=float32)
# 7.0
# -0.000279926361
# 1.0
# tf.Tensor([0.33308762], shape=(1,), dtype=float32)
# 8.0
# -5.8905624999999996e-05
# 1.0
# tf.Tensor([0.33333308], shape=(1,), dtype=float32)
# 9.0
# -9.734399999999999e-08
# 1.0
# tf.Tensor([0.33238193], shape=(1,), dtype=float32)
# 10.0
# -0.0005428900000000001
# 0.9940000000000001
# tf.Tensor([-0.23609911], shape=(1,), dtype=float32)
# 11.0
# -1.4915043999999999e-05
# 0.988036
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 12.0
# -3.2455809e-05
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 13.0
# -7.7018176e-05
# 0.976215137296
# tf.Tensor([-0.33333313], shape=(1,), dtype=float32)
# 14.0
# -0.0051586869760000004
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.001847624256
# 0.9645356993933907
# tf.Tensor([-0.31403595], shape=(1,), dtype=float32)
# 16.0
# -0.000128300929
# 1.0
# tf.Tensor([0.27045524], shape=(1,), dtype=float32)
# 17.0
# -0.008880423696
# 0.9940000000000001
# tf.Tensor([-0.09465511], shape=(1,), dtype=float32)
# 18.0
# -0.005534318449
# 1.0
# tf.Tensor([0.03505143], shape=(1,), dtype=float32)
# 19.0
# -0.007196977224999999
# 0.9940000000000001
# tf.Tensor([-0.3188326], shape=(1,), dtype=float32)
# 20.0
# -0.007225
# 1.0
# tf.Tensor([0.2687546], shape=(1,), dtype=float32)
# 21.0
# -0.006518140224999999
# 1.0
# tf.Tensor([0.33214605], shape=(1,), dtype=float32)
# 22.0
# -0.003144405625
# 1.0
# tf.Tensor([0.33294094], shape=(1,), dtype=float32)
# 23.0
# -0.000711555625
# 1.0
# tf.Tensor([0.33332828], shape=(1,), dtype=float32)
# 24.0
# -0.000788205625
# 1.0
# tf.Tensor([0.33333325], shape=(1,), dtype=float32)
# 1.0
# -0.000294980625
# 1.0
# tf.Tensor([0.3333272], shape=(1,), dtype=float32)
# 2.0
# -5.0623225e-05
# 1.0
# tf.Tensor([0.09211275], shape=(1,), dtype=float32)
# 3.0
# -4.5900625e-05
# 0.9940000000000001
# tf.Tensor([-0.33305237], shape=(1,), dtype=float32)
# 4.0
# -1.7639999999999997e-05
# 0.988036
# tf.Tensor([-0.3305174], shape=(1,), dtype=float32)
# 5.0
# -2.116e-05
# 1.0
# tf.Tensor([0.31804478], shape=(1,), dtype=float32)
# 6.0
# -0.000127260961
# 1.0
# tf.Tensor([0.3333331], shape=(1,), dtype=float32)
# 7.0
# -4.0640625e-05
# 1.0
# tf.Tensor([0.33333302], shape=(1,), dtype=float32)
# 8.0
# -5.0055625000000004e-05
# 1.0
# tf.Tensor([0.304364], shape=(1,), dtype=float32)
# 9.0
# -0.0007026210490000001
# 1.0
# tf.Tensor([0.16375849], shape=(1,), dtype=float32)
# 10.0
# -0.001741977169
# 0.9940000000000001
# tf.Tensor([-0.25385213], shape=(1,), dtype=float32)
# 11.0
# -0.022460717161000003
# 0.988036
# tf.Tensor([-0.33234894], shape=(1,), dtype=float32)
# 12.0
# -0.012479124099999999
# 0.982107784
# tf.Tensor([-0.29994112], shape=(1,), dtype=float32)
# 13.0
# -0.022076313561
# 0.976215137296
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 14.0
# -0.010577094024999999
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 15.0
# -0.000453008656
# 0.9645356993933907
# tf.Tensor([-0.33333293], shape=(1,), dtype=float32)
# 16.0
# -0.00011397697600000002
# 0.9587484851970303
# tf.Tensor([-0.13591829], shape=(1,), dtype=float32)
# 17.0
# -0.0020797248159999996
# 0.972124538541939
# tf.Tensor([0.01912854], shape=(1,), dtype=float32)
# 18.0
# -0.003715024401
# 1.0
# tf.Tensor([0.32802066], shape=(1,), dtype=float32)
# 19.0
# -0.010088193600000002
# 1.0
# tf.Tensor([0.06285802], shape=(1,), dtype=float32)
# 20.0
# -0.008625765625
# 0.9940000000000001
# tf.Tensor([-0.2974812], shape=(1,), dtype=float32)
# 21.0
# -0.006448089999999999
# 1.0
# tf.Tensor([0.3330139], shape=(1,), dtype=float32)
# 22.0
# -0.0038731952249999994
# 1.0
# tf.Tensor([0.2761538], shape=(1,), dtype=float32)
# 23.0
# -0.000886550625
# 1.0
# tf.Tensor([0.21982747], shape=(1,), dtype=float32)
# 24.0
# -0.0007994756250000001
# 1.0
# tf.Tensor([0.28738207], shape=(1,), dtype=float32)
# 1.0
# -0.000301890625
# 1.0
# tf.Tensor([0.3332622], shape=(1,), dtype=float32)
# 2.0
# -0.00033764062499999994
# 0.9940000000000001
# tf.Tensor([-0.09633414], shape=(1,), dtype=float32)
# 3.0
# -2.116e-05
# 1.0
# tf.Tensor([0.26761097], shape=(1,), dtype=float32)
# 4.0
# -8.1631225e-05
# 1.0
# tf.Tensor([0.11144515], shape=(1,), dtype=float32)
# 5.0
# -4.4555625e-05
# 1.0
# tf.Tensor([0.27166006], shape=(1,), dtype=float32)
# 6.0
# -4.4555625e-05
# 1.0
# tf.Tensor([0.26499647], shape=(1,), dtype=float32)
# 7.0
# -3.8130625000000006e-05
# 1.0
# tf.Tensor([0.33290032], shape=(1,), dtype=float32)
# 8.0
# -4.8650625e-05
# 0.9936841520113201
# tf.Tensor([-0.09857961], shape=(1,), dtype=float32)
# 9.0
# -0.0018065900159999998
# 1.0
# tf.Tensor([0.17303473], shape=(1,), dtype=float32)
# 10.0
# -0.011714598756
# 0.9940000000000001
# tf.Tensor([-0.24395745], shape=(1,), dtype=float32)
# 11.0
# -0.020982971025
# 1.0
# tf.Tensor([0.3330156], shape=(1,), dtype=float32)
# 12.0
# -0.021157157025
# 0.9940000000000001
# tf.Tensor([-0.1318439], shape=(1,), dtype=float32)
# 13.0
# -0.024212604816
# 0.988036
# tf.Tensor([-0.26923192], shape=(1,), dtype=float32)
# 14.0
# -0.018863099648999997
# 0.982107784
# tf.Tensor([-0.3228836], shape=(1,), dtype=float32)
# 15.0
# -0.013855408680999997
# 0.976215137296
# tf.Tensor([-0.33039662], shape=(1,), dtype=float32)
# 16.0
# -0.0075921596890000005
# 0.9703578464722239
# tf.Tensor([-0.33042806], shape=(1,), dtype=float32)
# 17.0
# -0.001390618681
# 0.9645356993933907
# tf.Tensor([-0.3199134], shape=(1,), dtype=float32)
# 18.0
# -0.001478633209
# 1.0
# tf.Tensor([0.32875308], shape=(1,), dtype=float32)
# 19.0
# -0.018321788164
# 1.0
# tf.Tensor([0.22365879], shape=(1,), dtype=float32)
# 20.0
# -0.007085430625000001
# 1.0
# tf.Tensor([0.08867538], shape=(1,), dtype=float32)
# 21.0
# -0.007215822916000001
# 1.0
# tf.Tensor([0.33312583], shape=(1,), dtype=float32)
# 22.0
# -0.003009839044
# 1.0
# tf.Tensor([0.21885733], shape=(1,), dtype=float32)
# 23.0
# -0.0007987971689999999
# 1.0
# tf.Tensor([0.16891514], shape=(1,), dtype=float32)
# 24.0
# -0.0007093699560000001
# 1.0
# tf.Tensor([0.14608215], shape=(1,), dtype=float32)
# 1.0
# -0.0006682225
# 0.9940000000000001
# tf.Tensor([-0.12769273], shape=(1,), dtype=float32)
# 2.0
# -0.00024025000000000004
# 1.0
# tf.Tensor([0.1301032], shape=(1,), dtype=float32)
# 3.0
# -0.0001868689
# 1.0
# tf.Tensor([0.11917239], shape=(1,), dtype=float32)
# 4.0
# -7.3034116e-05
# 0.9940000000000001
# tf.Tensor([-0.21435654], shape=(1,), dtype=float32)
# 5.0
# -1.444e-05
# 0.988036
# tf.Tensor([-0.32750794], shape=(1,), dtype=float32)
# 6.0
# -1.6000000000000003e-05
# 0.982107784
# tf.Tensor([-0.3280201], shape=(1,), dtype=float32)
# 7.0
# -1.6809999999999997e-05
# 0.976215137296
# tf.Tensor([-0.0872377], shape=(1,), dtype=float32)
# 8.0
# -1.444e-05
# 1.0
# tf.Tensor([0.28001106], shape=(1,), dtype=float32)
# 9.0
# -0.000558802321
# 0.9932166969880737
# tf.Tensor([-0.3221117], shape=(1,), dtype=float32)
# 10.0
# -3.6404640000000004e-06
# 0.9872573968061452
# tf.Tensor([-0.31045273], shape=(1,), dtype=float32)
# 11.0
# -0.0007640801640000001
# 0.9813338524253084
# tf.Tensor([-0.05333337], shape=(1,), dtype=float32)
# 12.0
# -0.00285156
# 0.9754458493107564
# tf.Tensor([-0.02740094], shape=(1,), dtype=float32)
# 13.0
# -0.003146536836
# 1.0
# tf.Tensor([0.13935772], shape=(1,), dtype=float32)
# 14.0
# -0.007209708099999999
# 0.9940000000000001
# tf.Tensor([-0.32772893], shape=(1,), dtype=float32)
# 15.0
# -0.002929299129
# 1.0
# tf.Tensor([0.05206507], shape=(1,), dtype=float32)
# 16.0
# -0.0036479184039999992
# 1.0
# tf.Tensor([0.33243614], shape=(1,), dtype=float32)
# 17.0
# -0.005093248689000001
# 1.0
# tf.Tensor([0.32636735], shape=(1,), dtype=float32)
# 18.0
# -0.005805982808999999
# 1.0
# tf.Tensor([0.3305172], shape=(1,), dtype=float32)
# 19.0
# -0.006451784328999999
# 1.0
# tf.Tensor([0.32392204], shape=(1,), dtype=float32)
# 20.0
# -0.0034845409
# 1.0
# tf.Tensor([0.33288318], shape=(1,), dtype=float32)
# 21.0
# -0.0006923213440000001
# 1.0
# tf.Tensor([0.3319124], shape=(1,), dtype=float32)
# 22.0
# -0.000664763089
# 1.0
# tf.Tensor([0.3284295], shape=(1,), dtype=float32)
# 23.0
# -0.0007492811289999999
# 1.0
# tf.Tensor([0.30756122], shape=(1,), dtype=float32)
# 24.0
# -0.000585543204
# 0.9940000000000001
# tf.Tensor([-0.00626065], shape=(1,), dtype=float32)
# 1.0
# -0.00048841
# 0.988036
# tf.Tensor([-0.33032173], shape=(1,), dtype=float32)
# 2.0
# -1.936e-05
# 1.0
# tf.Tensor([0.12378156], shape=(1,), dtype=float32)
# 3.0
# -0.00015562562500000003
# 1.0
# tf.Tensor([0.33188146], shape=(1,), dtype=float32)
# 4.0
# -4.5900625e-05
# 0.9940000000000001
# tf.Tensor([-0.06275377], shape=(1,), dtype=float32)
# 5.0
# -1.5210000000000002e-05
# 0.988036
# tf.Tensor([-0.21852544], shape=(1,), dtype=float32)
# 6.0
# -2.025e-05
# 0.982107784
# tf.Tensor([-0.32736856], shape=(1,), dtype=float32)
# 7.0
# -2.025e-05
# 1.0
# tf.Tensor([0.19368307], shape=(1,), dtype=float32)
# 8.0
# -0.000202009369
# 1.0
# tf.Tensor([0.33123833], shape=(1,), dtype=float32)
# 9.0
# -4.8024899999999995e-05
# 1.0
# tf.Tensor([0.33329612], shape=(1,), dtype=float32)
# 10.0
# -1.1710084e-05
# 0.993431473620376
# tf.Tensor([-0.33242583], shape=(1,), dtype=float32)
# 11.0
# -0.00010658497599999998
# 0.9874708847786537
# tf.Tensor([-0.24909157], shape=(1,), dtype=float32)
# 12.0
# -0.0013218314489999998
# 1.0
# tf.Tensor([0.32889205], shape=(1,), dtype=float32)
# 13.0
# -0.0008487316890000001
# 0.9940000000000001
# tf.Tensor([-0.33328962], shape=(1,), dtype=float32)
# 14.0
# -0.001271706921
# 0.988036
# tf.Tensor([-0.32804725], shape=(1,), dtype=float32)
# 15.0
# -0.015768076041
# 0.982107784
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 16.0
# -0.014660850724
# 0.976215137296
# tf.Tensor([-0.3333308], shape=(1,), dtype=float32)
# 17.0
# -0.0022906753210000003
# 0.9703578464722239
# tf.Tensor([-0.33333325], shape=(1,), dtype=float32)
# 18.0
# -0.002278725696
# 0.9645356993933907
# tf.Tensor([-0.06472177], shape=(1,), dtype=float32)
# 19.0
# -0.00242064
# 0.9587484851970303
# tf.Tensor([-0.01650734], shape=(1,), dtype=float32)
# 20.0
# -0.0005107599999999999
# 0.952995994285848
# tf.Tensor([-0.24658507], shape=(1,), dtype=float32)
# 21.0
# -0.00058564
# 0.9472780183201329
# tf.Tensor([-0.01723963], shape=(1,), dtype=float32)
# 22.0
# -0.0005522500000000001
# 1.0
# tf.Tensor([0.32658482], shape=(1,), dtype=float32)
# 23.0
# -0.001972692225
# Cumulated reward: 230.58173266764973
# 1.0
# tf.Tensor([0.33029482], shape=(1,), dtype=float32)
# 24.0
# -0.000749390625
# {'ramping': 1.7999619,
#  '1-load_factor': 1.0329880173230521,
#  'average_daily_peak': 1.3366019,
#  'peak_demand': 1.2517856,
#  'net_electricity_consumption': 0.96348643,
#  'quadratic': 1.2193587,
#  'total': 1.2673637578094064}

# %%
# Plotting winter operation
interval = range(0,8759)
plt.figure(figsize=(16,5))
plt.plot(env.net_electric_consumption_no_pv_no_storage[interval])
plt.plot(env.net_electric_consumption_no_storage[interval])
plt.plot(env.net_electric_consumption[interval], '--')

plt.xlabel('time (hours)')
plt.ylabel('kW')
plt.legend(['Electricity demand without storage or generation (kW)', 'Electricity demand with PV generation and without storage(kW)', 'Electricity demand with PV generation and using DDPG for storage(kW)'])
plt.savefig('plots/profile.png')

# %%
# Plotting winter operation
interval = range(5000,5200)
plt.figure(figsize=(16,5))
plt.plot(env.net_electric_consumption_no_pv_no_storage[interval])
plt.plot(env.net_electric_consumption_no_storage[interval])
plt.plot(env.net_electric_consumption[interval], '--')
plt.xlabel('time (hours)')
plt.ylabel('kW')
plt.legend(['Electricity demand without storage or generation (kW)', 'Electricity demand with PV generation and without storage(kW)', 'Electricity demand with PV generation and using SAC for storage(kW)'])
plt.savefig('plots/profile_interval.png')

# %%
print("Electric consumption without central DDPG agent: " + str(np.sum(env.net_electric_consumption_no_storage)) + "W")
print("Electric consumption with central DDPG agent: " + str(np.sum(env.net_electric_consumption)) + "W")
# Out:
# Electric consumption without central DDPG agent: 74536.03W
# Electric consumption with central DDPG agent: 62742.605W
